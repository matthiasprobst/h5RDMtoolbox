# %% [markdown]
# # Inspecting the File content
#
# To get an overview of the file content, a tree-view representation is provided. It can be called using `.dump()`. This, however, is only possible in notebooks. Outside of it (e.g. in a normal python console) call `.sdump()` (string-dump) to get a "raw", non-interactive, tree view.
#
# However, we are in a notebook environment here, so let's use `dump()`:

# %%
import h5rdmtoolbox as h5tbx
from h5rdmtoolbox import tutorial

# get some example files:
list_of_hdf_filenames = tutorial.Database.generate_test_files()

# dump the content of the first file in the list:
with h5tbx.File(list_of_hdf_filenames[0]) as h5:
    h5.dump()
# Out:
# Failed to import module h5tbx
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }
#
#
# /* Tooltip container */
# .tooltip {
# position: relative;
# display: inline-block;
# cursor: pointer;
# }
#
# /* Tooltip text */
# .tooltip .tooltiptext {
# visibility: hidden;
# width: 300px;
# background-color: #555;
# color: #fff;
# text-align: center;
# border-radius: 6px;
# padding: 5px;
# position: absolute;
# z-index: 1;
# bottom: 125%;
# left: 50%;
# margin-left: -60px;
# opacity: 0;
# transition: opacity 0.3s;
# }
#
# /* Show the tooltip on hover */
# .tooltip:hover .tooltiptext {
# visibility: visible;
# opacity:  1;
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--6149892200" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--6149892200">
#                         /<span>(4)</span></label>
#
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__db_file_type__ : piv_case</li><li style="list-style-type: none; font-style: italic">contact_person : John</li>
#                     </ul>
#
#                 <ul id="ds-1-/u-6152360900" class="h5tb-var-list">
#                     <input id="ds-2-/u-6152363400" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/u-6152363400">u</label>
#                     <span class="h5tb-dims">(2, 5, 64, x: 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : u-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/v-6153065800" class="h5tb-var-list">
#                     <input id="ds-2-/v-6153068500" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/v-6153068500">v</label>
#                     <span class="h5tb-dims">(2, 5, 64, x: 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : v-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/x-6153451400" class="h5tb-var-list">
#                     <input id="ds-2-/x-6153455300" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/x-6153455300">x</label>
#                     <span class="h5tb-dims">(86) [int32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : x-coordinate</li><li style="list-style-type: none; font-style: italic">units : m</li>
#                 </ul>
#                 </ul>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds-timeAverages-6153731800" type="checkbox" >
#                         <label style="font-weight: bold" for="group-ds-timeAverages-6153731800">
#                         timeAverages<span>(2)</span></label>
#
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : time averaged data</li>
#                     </ul>
#
#                 <ul id="ds-1-/timeAverages/u-6154723800" class="h5tb-var-list">
#                     <input id="ds-2-/timeAverages/u-6154726500" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/timeAverages/u-6154726500">u</label>
#                     <span class="h5tb-dims">(2, 64, 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : mean u-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/timeAverages/v-6155119100" class="h5tb-var-list">
#                     <input id="ds-2-/timeAverages/v-6155122700" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/timeAverages/v-6155122700">v</label>
#                     <span class="h5tb-dims">(2, 64, 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : mean v-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>

# %% [markdown]
# ## User-defined representation
#
# Every convention that is selected may have a different way of displaying the content. For the built-in convention "h5tbx", the attribute "units" is put in square brackets behind the dataset name and thus is not listed as an attribute:

# %%
h5tbx.use('h5tbx')

with h5tbx.File(list_of_hdf_filenames[0]) as h5:
    h5.dump()
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }
#
#
# /* Tooltip container */
# .tooltip {
# position: relative;
# display: inline-block;
# cursor: pointer;
# }
#
# /* Tooltip text */
# .tooltip .tooltiptext {
# visibility: hidden;
# width: 300px;
# background-color: #555;
# color: #fff;
# text-align: center;
# border-radius: 6px;
# padding: 5px;
# position: absolute;
# z-index: 1;
# bottom: 125%;
# left: 50%;
# margin-left: -60px;
# opacity: 0;
# transition: opacity 0.3s;
# }
#
# /* Show the tooltip on hover */
# .tooltip:hover .tooltiptext {
# visibility: visible;
# opacity:  1;
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--6177946500" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--6177946500">
#                         /<span>(4)</span></label>
#
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__db_file_type__ : piv_case</li><li style="list-style-type: none; font-style: italic">contact_person : John</li>
#                     </ul>
#
#                 <ul id="ds-1-/u-6179664700" class="h5tb-var-list">
#                     <input id="ds-2-/u-6179667400" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/u-6179667400">u</label>
#                     <span class="h5tb-dims">(2, 5, 64, x: 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : u-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/v-6180157900" class="h5tb-var-list">
#                     <input id="ds-2-/v-6180161900" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/v-6180161900">v</label>
#                     <span class="h5tb-dims">(2, 5, 64, x: 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : v-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/x-6180487100" class="h5tb-var-list">
#                     <input id="ds-2-/x-6180489500" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/x-6180489500">x</label>
#                     <span class="h5tb-dims">(86) [int32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : x-coordinate</li><li style="list-style-type: none; font-style: italic">units : m</li>
#                 </ul>
#                 </ul>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds-timeAverages-6180704300" type="checkbox" >
#                         <label style="font-weight: bold" for="group-ds-timeAverages-6180704300">
#                         timeAverages<span>(2)</span></label>
#
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : time averaged data</li>
#                     </ul>
#
#                 <ul id="ds-1-/timeAverages/u-6181633900" class="h5tb-var-list">
#                     <input id="ds-2-/timeAverages/u-6181636600" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/timeAverages/u-6181636600">u</label>
#                     <span class="h5tb-dims">(2, 64, 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : mean u-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/timeAverages/v-6182008300" class="h5tb-var-list">
#                     <input id="ds-2-/timeAverages/v-6182010800" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/timeAverages/v-6182010800">v</label>
#                     <span class="h5tb-dims">(2, 64, 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : mean v-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>
