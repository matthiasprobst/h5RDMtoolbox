# %% [markdown]
# # Visualization
#
# As the return value of a sliced dataset is a `xarray.DataArray` instead of a `numpy.ndarray` plotting features of `xarray` is used. For more information about `xarray` see https://docs.xarray.dev/en/stable/
#
# A a more experimental level, some HDF5 datasets or multiple HDF5 datasets as a tuple can be nicely 3D-rendered by the `ipyvolume` package, see last section

# %%
import h5rdmtoolbox as h5tbx
h5tbx.use(None)

import matplotlib.pyplot as plt
import numpy as np

# %%
with h5tbx.File() as h5:
    dsx = h5.create_dataset('x', data=np.linspace(0, 10, 20), attrs=dict(units='mm', long_name='x'), make_scale=True)
    dsy = h5.create_dataset('y', data=np.linspace(0, 5, 10), attrs=dict(units='mm', long_name='y'), make_scale=True)
    dsz = h5.create_dataset('z', data=np.linspace(0, 3, 4), attrs=dict(units='mm', long_name='z'), make_scale=True)
    h5.create_dataset('data', data=np.random.random((10, 20)), attrs=dict(units='m/s', long_name='velocity'), attach_scales=(dsy, dsx))
    
    xx, yy, zz = np.meshgrid(dsy.values[:], dsz.values[:], dsx.values[:])
    
    h5.create_dataset('u', data=np.sin(xx), attrs=dict(units='m/s', long_name='x_velocity'), attach_scales=(dsz, dsy, dsx))
    h5.create_dataset('v', data=yy, attrs=dict(units='m/s', long_name='y_velocity'), attach_scales=(dsz, dsy, dsx))
    h5.create_dataset('w', data=np.ones((4, 10, 20)), attrs=dict(units='m/s', long_name='z_velocity'), attach_scales=(dsz, dsy, dsx))
    h5.dump()
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--5107553800" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--5107553800">
#                         /<span>(7)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 1.0.0</li>
#                     </ul>
#
#                 <ul id="ds-1-/data-5109712400" class="h5tb-var-list">
#                     <input id="ds-2-/data-5109714800" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/data-5109714800">data</label>
#                     <span class="h5tb-dims">(y: 10, x: 20) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : velocity</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/u-5110154200" class="h5tb-var-list">
#                     <input id="ds-2-/u-5110156500" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/u-5110156500">u</label>
#                     <span class="h5tb-dims">(z: 4, y: 10, x: 20) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : x_velocity</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/v-5110554700" class="h5tb-var-list">
#                     <input id="ds-2-/v-5110557000" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/v-5110557000">v</label>
#                     <span class="h5tb-dims">(z: 4, y: 10, x: 20) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : y_velocity</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/w-5110929800" class="h5tb-var-list">
#                     <input id="ds-2-/w-5110932000" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/w-5110932000">w</label>
#                     <span class="h5tb-dims">(z: 4, y: 10, x: 20) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : z_velocity</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/x-5111151900" class="h5tb-var-list">
#                     <input id="ds-2-/x-5111153800" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/x-5111153800">x</label>
#                     <span class="h5tb-dims">(20) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : x</li><li style="list-style-type: none; font-style: italic">units : mm</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/y-5111380000" class="h5tb-var-list">
#                     <input id="ds-2-/y-5111383600" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/y-5111383600">y</label>
#                     <span class="h5tb-dims">(10) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : y</li><li style="list-style-type: none; font-style: italic">units : mm</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/z-5111640600" class="h5tb-var-list">
#                     <input id="ds-2-/z-5111642600" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/z-5111642600">z</label>
#                     <span class="h5tb-dims">(4) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : z</li><li style="list-style-type: none; font-style: italic">units : mm</li>
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </div>

# %%
with h5tbx.File(h5.hdf_filename) as h5:
    # some plotting
    plt.figure()
    h5['data'][:].plot()
    plt.show()
    
    plt.figure()
    h5['data'][:].plot.contourf()
    plt.figure()
    plt.show()

# %%
with h5tbx.File(h5.hdf_filename) as h5:
    h5['data'][:].plot.hist()
    plt.show()

# %%
with h5tbx.File(h5.hdf_filename) as h5:
    h5.dump()
    d = h5['data'][:, 0]
    # d.plot.line(marker='o')
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--5600244100" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--5600244100">
#                         /<span>(7)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 1.0.0</li>
#                     </ul>
#
#                 <ul id="ds-1-/data-5603856600" class="h5tb-var-list">
#                     <input id="ds-2-/data-5603861800" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/data-5603861800">data</label>
#                     <span class="h5tb-dims">(y: 10, x: 20) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : velocity</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/u-5604830800" class="h5tb-var-list">
#                     <input id="ds-2-/u-5604834600" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/u-5604834600">u</label>
#                     <span class="h5tb-dims">(z: 4, y: 10, x: 20) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : x_velocity</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/v-5605479500" class="h5tb-var-list">
#                     <input id="ds-2-/v-5605483600" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/v-5605483600">v</label>
#                     <span class="h5tb-dims">(z: 4, y: 10, x: 20) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : y_velocity</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/w-5606121100" class="h5tb-var-list">
#                     <input id="ds-2-/w-5606124200" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/w-5606124200">w</label>
#                     <span class="h5tb-dims">(z: 4, y: 10, x: 20) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : z_velocity</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/x-5606487400" class="h5tb-var-list">
#                     <input id="ds-2-/x-5606491600" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/x-5606491600">x</label>
#                     <span class="h5tb-dims">(20) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : x</li><li style="list-style-type: none; font-style: italic">units : mm</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/y-5606956800" class="h5tb-var-list">
#                     <input id="ds-2-/y-5606960300" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/y-5606960300">y</label>
#                     <span class="h5tb-dims">(10) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : y</li><li style="list-style-type: none; font-style: italic">units : mm</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/z-5607301800" class="h5tb-var-list">
#                     <input id="ds-2-/z-5607305300" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/z-5607305300">z</label>
#                     <span class="h5tb-dims">(4) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : z</li><li style="list-style-type: none; font-style: italic">units : mm</li>
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </div>

# %%
from h5rdmtoolbox.extensions import vector
with h5tbx.File(h5.hdf_filename) as h5:
    ds = h5.Vector(u=h5.u, v=h5.v)
    ds[2, :, :].plot.quiver(x='x', y='y', u='u', v='v')

# %% [markdown]
# ## Using ipyvolume

# %%
#from h5rdmtoolbox.extensions import ipyvolume

# %%
# with h5tbx.File(h5.hdf_filename) as h5:
#     vec =  h5.Vector(u=h5.u, v=h5.v, w=h5.w)
#     ipv_quiver = vec[:, :, :].ipyvolume.quiver(x='x',y='y',z='z',
#                                               u='u',v='u',w='u')
#     ipv_quiver.view(-10, -40, 2.5)
#     ipv_quiver.show()

# %%
# with h5tbx.File(h5.hdf_filename) as h5:
#     ipv_surf = h5.data[:].ipyvolume.plot()
#     ipv_surf.view(-10, -40, 2.5)
#     ipv_surf.show()
