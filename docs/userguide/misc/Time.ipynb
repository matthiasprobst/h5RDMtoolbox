# %% [markdown]
# # Working with time data
#
# Give your file, group or dataset a timestamp by calling `.write_iso_timestamp()`

# %%
import h5rdmtoolbox as h5tbx

with h5tbx.File() as h5:
    h5.attrs.write_iso_timestamp()
    h5.dump()
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }
#
#
# /* Tooltip container */
# .tooltip {
# position: relative;
# display: inline-block;
# cursor: pointer;
# }
#
# /* Tooltip text */
# .tooltip .tooltiptext {
# visibility: hidden;
# width: 300px;
# background-color: #555;
# color: #fff;
# text-align: center;
# border-radius: 6px;
# padding: 5px;
# position: absolute;
# z-index: 1;
# bottom: 125%;
# left: 50%;
# margin-left: -60px;
# opacity: 0;
# transition: opacity 0.3s;
# }
#
# /* Show the tooltip on hover */
# .tooltip:hover .tooltiptext {
# visibility: visible;
# opacity:  1;
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--11327305900" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--11327305900">
#                         /<span>(0)</span></label>
#
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">timestamp: 2024-06-18T13:46:11.143965</li>
#                     </ul>
# </li>
# </ul>
# </div>

# %% [markdown]
# HDF5 cannot store `datetime` objects. The solution is to store them as string-datasets. Therefore, `datetime` is written to the HDF5 datasets in ISO-format. When data is requested, it is converted back to `numpy.datetime64` format and fed into the `xarray` object. Note, that you may use the method `create_time_dataset` instead of constructing the string dataset yourself. In fact, this is recommended, because some attributes must be set in order to identify a dataset as a "time-data-dataset":

# %%
import datetime

# %%
with h5tbx.File() as h5:
    h5.create_time_dataset('time',
                           data=[datetime.datetime.now(),
                                 datetime.datetime.now()+datetime.timedelta(hours=1),
                                 datetime.datetime.now()+datetime.timedelta(hours=3)],
                           time_format='iso', make_scale=True)
    h5.create_dataset('vel', data=[1,2,-3], attach_scale='time')
    v = h5.vel[()]
    t = h5.time[()]
    h5.dump()
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }
#
#
# /* Tooltip container */
# .tooltip {
# position: relative;
# display: inline-block;
# cursor: pointer;
# }
#
# /* Tooltip text */
# .tooltip .tooltiptext {
# visibility: hidden;
# width: 300px;
# background-color: #555;
# color: #fff;
# text-align: center;
# border-radius: 6px;
# padding: 5px;
# position: absolute;
# z-index: 1;
# bottom: 125%;
# left: 50%;
# margin-left: -60px;
# opacity: 0;
# transition: opacity 0.3s;
# }
#
# /* Show the tooltip on hover */
# .tooltip:hover .tooltiptext {
# visibility: visible;
# opacity:  1;
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--11442521100" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--11442521100">
#                         /<span>(2)</span></label>
#
# <ul class="h5tb-attr-list">
#                     </ul>
#
#                         <ul id="ds-1-/time-114440575001" class="h5tb-var-list">
#                         <input id="ds-2-/time-114440575002" class="h5tb-varname-in" type="checkbox" >
#                         <label class='h5tb-varname'
#                         for="ds-2-/time-114440575002">time<a href="https://schema.org/DateTime" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/type_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">@type=https://schema.org/DateTime</span></a></label>: [|S26]
#
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">time_format<a href="https://matthiasprobst.github.io/pivmeta#timeFormat" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/iri_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">https://matthiasprobst.github.io/pivmeta#timeFormat</span></a>: %Y-%m-%dT%H:%M:%S.%f</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/vel-11447886200" class="h5tb-var-list">
#                     <input id="ds-2-/vel-11447891600" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/vel-11447891600">vel</label>
#                     <span class="h5tb-dims">(time: 3) [int32]</span>
#                 <ul class="h5tb-attr-list">
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </div>

# %%
v.plot()
