# %% [markdown]
# # Serverless HDF Database
#
# No classic server client-client concept is used. Instead a HDF file is created with external links to root groups of HDF files that included to the database.

# %%
from h5rdmtoolbox import h5database as h5db
from h5rdmtoolbox import generate_temporary_directory
from h5rdmtoolbox import tutorial

# %%
tocdir = generate_temporary_directory('test_repo')
tutorial.Database.build_test_repo(tocdir)

# %% [markdown]
# ## H5Repo - External link based reository
#
# Initialize a `H5Repo` object and specify the root directory under which HDF files are placed:

# %%
repo = h5db.H5repo(tocdir)

# %% [markdown]
# The object creates a `toc` file (toc=table of content) which is a HDF5 file with external links to the found HDF files:

# %%
repo.toc_filename.name
# Out:
# 'test_repo0_toc.hdf'

# %% [markdown]
# The content can be dumped to the screen as a (pandas-) table:

# %%
repo.dump(full_path=False)  # minimizes the output (no full folder path is shown)
# Out:
#              File name Folder path
# 0   repofile_00002.hdf        d111
# 1   repofile_00007.hdf        d111
# 2   repofile_00011.hdf        d111
# 3   repofile_00022.hdf        d111
# 4   repofile_00023.hdf        d111
# ..                 ...         ...
# 95  repofile_00057.hdf          d3
# 96  repofile_00062.hdf          d3
# 97  repofile_00072.hdf          d3
# 98  repofile_00085.hdf          d3
# 99  repofile_00095.hdf          d3
#
# [100 rows x 2 columns]

# %% [markdown]
# The entries can be indexed and the file content is shown:

# %%
repo[0]
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
#
# .h5tb-unit {
#     width: 96px;
#     white-space: nowrap;
#     padding-right: 2px;
#     text-align: right;
#     color: #555;
#     font-style: italic;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: #fff;
#     padding-bottom: 6px;
#     color: #555;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: #fff;
# }
#
# .h5tb-dim-highlight {
#     background-color: rgba(3, 169, 244, .2);
#     cursor: pointer;
# }</style></head>
# <p>repofile_00002.hdf</p>
# <p>Check resuted in 1 issues.</p>
#
# <div class='h5tb-warp'>
#
#           <ul style="list-style-type: none;" class="h5grp-sections">
#                 <li>
#                     <input id="group-ds-/-3336422900" type="checkbox" checked>
#                     <label style="font-weight: bold" for="group-ds-/-3336422900">
#                     /<span>(3)</span></label>
#
#
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__db_file_type__ : piv_case</li><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.1.3</li><li style="list-style-type: none; font-style: italic">__standard_name_table__ : EmptyStandardizedNameTable-v0</li><li style="list-style-type: none; font-style: italic">__wrcls__ : H5File</li><li style="list-style-type: none; font-style: italic">operator : Mike</li>
#                 </ul>
#
#                 <ul id="ds-1-/u-3338059300" class="h5tb-var-list">
#                 <input id="ds-2-/u-3338061700" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/u-3338061700">u</label>
#                 <span class="h5tb-dims">(2, 5, 64, 86, 2)</span>  [
#                 <span class="h5tb-unit">m/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : u-component</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/v-3338400600" class="h5tb-var-list">
#                 <input id="ds-2-/v-3338402800" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/v-3338402800">v</label>
#                 <span class="h5tb-dims">(2, 5, 64, 86, 2)</span>  [
#                 <span class="h5tb-unit">m/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : v-component</li>
#
#                 </ul>
#
#              </ul>
#
#
#           <ul style="list-style-type: none;" class="h5grp-sections">
#                 <li>
#                     <input id="group-ds-/timeAverages-3338535500" type="checkbox" >
#                     <label style="font-weight: bold" for="group-ds-/timeAverages-3338535500">
#                     timeAverages<span>(2)</span></label>
#
#
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : time averaged data</li>
#                 </ul>
#
#                 <ul id="ds-1-/timeAverages/u-3339208700" class="h5tb-var-list">
#                 <input id="ds-2-/timeAverages/u-3339211100" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/timeAverages/u-3339211100">u</label>
#                 <span class="h5tb-dims">(2, 64, 86, 2)</span>  [
#                 <span class="h5tb-unit">m/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : mean u-component</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/timeAverages/v-3339483700" class="h5tb-var-list">
#                 <input id="ds-2-/timeAverages/v-3339485800" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/timeAverages/v-3339485800">v</label>
#                 <span class="h5tb-dims">(2, 64, 86, 2)</span>  [
#                 <span class="h5tb-unit">m/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : mean v-component</li>
#
#                 </ul>
#
#              </ul>
#
# </li>
# </ul>
# </li>
# </ul>
# </div>

# %% [markdown]
# ### Filtering
#
# The repository can be filtered in a HDF5-like syntax. First import all filter classes from the module `filter_classes`:

# %%
from h5rdmtoolbox.h5database.filter_classes import *
# repo.list_attribute_values('operator', '/')

# %% [markdown]
# The filter method requires an object `Entry`. It is the access location within a file, here the group "operation_point" in the root group. In the example the repository is filtered for the attribute "long_name" equal to "Operation point data group". A sub-repository is returend which is again an HDF5 file with external links - but this time only to the HDF files matching the filter request:

# %%
# %%time
sub_repo = repo.filter(Entry['/operation_point'].attrs['long_name'] == 'Operation point data group')
# Out:
# CPU times: total: 156 ms
# Wall time: 145 ms

# %%
sub_repo.dump(False)
# Out:
#              File name Folder path
# 0   repofile_00022.hdf        d111
# 1   repofile_00023.hdf        d111
# 2   repofile_00027.hdf        d111
# 3   repofile_00034.hdf        d111
# 4   repofile_00035.hdf        d111
# 5   repofile_00045.hdf        d111
# 6   repofile_00047.hdf        d111
# 7   repofile_00060.hdf        d111
# 8   repofile_00069.hdf        d111
# 9   repofile_00080.hdf        d111
# 10  repofile_00097.hdf        d111
# 11  repofile_00001.hdf         d11
# 12  repofile_00003.hdf         d11
# 13  repofile_00005.hdf         d11
# 14  repofile_00044.hdf         d11
# 15  repofile_00058.hdf         d11
# 16  repofile_00078.hdf         d11
# 17  repofile_00000.hdf          d1
# 18  repofile_00004.hdf          d1
# 19  repofile_00009.hdf          d1
# 20  repofile_00010.hdf          d1
# 21  repofile_00021.hdf          d1
# 22  repofile_00030.hdf          d1
# 23  repofile_00036.hdf          d1
# 24  repofile_00037.hdf          d1
# 25  repofile_00048.hdf          d1
# 26  repofile_00052.hdf          d1
# 27  repofile_00066.hdf          d1
# 28  repofile_00067.hdf          d1
# 29  repofile_00077.hdf          d1
# 30  repofile_00082.hdf          d1
# 31  repofile_00083.hdf          d1
# 32  repofile_00014.hdf         d21
# 33  repofile_00016.hdf         d21
# 34  repofile_00020.hdf         d21
# 35  repofile_00026.hdf         d21
# 36  repofile_00028.hdf         d21
# 37  repofile_00053.hdf         d21
# 38  repofile_00070.hdf         d21
# 39  repofile_00076.hdf         d21
# 40  repofile_00079.hdf         d21
# 41  repofile_00089.hdf         d21
# 42  repofile_00099.hdf         d21
# 43  repofile_00015.hdf          d2
# 44  repofile_00019.hdf          d2
# 45  repofile_00029.hdf          d2
# 46  repofile_00039.hdf          d2
# 47  repofile_00049.hdf          d2
# 48  repofile_00055.hdf          d2
# 49  repofile_00061.hdf          d2
# 50  repofile_00086.hdf          d2
# 51  repofile_00091.hdf          d2
# 52  repofile_00012.hdf          d3
# 53  repofile_00017.hdf          d3
# 54  repofile_00040.hdf          d3
# 55  repofile_00056.hdf          d3
# 56  repofile_00062.hdf          d3
# 57  repofile_00072.hdf          d3
# 58  repofile_00085.hdf          d3

# %% [markdown]
# The elsaped time for the filter request and building the new HDF toc-file is:

# %%
sub_repo.elapsed_time  # [s]
# Out:
# 0.12194709999999986

# %% [markdown]
# Evaluating the sub-repository is quite straight forward as we are still working with HDF5 files. Let's plot data from the filter results:

# %%
# %%time
import matplotlib.pyplot as plt

plt.figure()
for r in sub_repo:
    with r as h5:
        if 'operation_point' in h5:
            plt.scatter(h5['operation_point']['vfr'].attrs['mean'], h5['operation_point']['ptot'].attrs['mean'])
plt.xlabel('vfr')
plt.ylabel('ptot')
plt.show()
# Out:
# CPU times: total: 1.11 s
# Wall time: 1.17 s

# %% [markdown]
# ## H5Files - Accessing multiple HDF files
#
# This concepts assumes that we already know the HDF files. This might be a result from above

# %%
from h5rdmtoolbox.h5database import H5Files

# %%
sub_repo[0:3]
# Out:
# [<h5rdmtoolbox.h5database.h5repo.SingleResult at 0x2664eb6e550>,
#  <h5rdmtoolbox.h5database.h5repo.SingleResult at 0x2664eb6e220>,
#  <h5rdmtoolbox.h5database.h5repo.SingleResult at 0x2664eb6e850>]

# %%
with H5Files(*[sr.filename for sr in sub_repo[0:4]]) as h5files:
    print(h5files.keys())
    h5files[list(h5files.keys())[0]].dump()
# Out:
# dict_keys(['repofile_00022', 'repofile_00023', 'repofile_00027', 'repofile_00034'])
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
#
# .h5tb-unit {
#     width: 96px;
#     white-space: nowrap;
#     padding-right: 2px;
#     text-align: right;
#     color: #555;
#     font-style: italic;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: #fff;
#     padding-bottom: 6px;
#     color: #555;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: #fff;
# }
#
# .h5tb-dim-highlight {
#     background-color: rgba(3, 169, 244, .2);
#     cursor: pointer;
# }</style></head>
# <p>repofile_00022.hdf</p>
# <p>Check resuted in 1 issues.</p>
#
# <div class='h5tb-warp'>
#
#           <ul style="list-style-type: none;" class="h5grp-sections">
#                 <li>
#                     <input id="group-ds-/-4780675000" type="checkbox" checked>
#                     <label style="font-weight: bold" for="group-ds-/-4780675000">
#                     /<span>(1)</span></label>
#
#
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__db_file_type__ : fan_case</li><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.1.3</li><li style="list-style-type: none; font-style: italic">__standard_name_table__ : EmptyStandardizedNameTable-v0</li><li style="list-style-type: none; font-style: italic">__wrcls__ : H5File</li><li style="list-style-type: none; font-style: italic">operator : Mike</li>
#                 </ul>
#
#           <ul style="list-style-type: none;" class="h5grp-sections">
#                 <li>
#                     <input id="group-ds-/operation_point-4781089400" type="checkbox" >
#                     <label style="font-weight: bold" for="group-ds-/operation_point-4781089400">
#                     operation_point<span>(2)</span></label>
#
#
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : Operation point data group</li>
#                 </ul>
#
#                 <ul id="ds-1-/operation_point/ptot-4781765500" class="h5tb-var-list">
#                 <input id="ds-2-/operation_point/ptot-4781767700" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/operation_point/ptot-4781767700">ptot</label>
#                 <span class="h5tb-dims">(100,)</span>  [
#                 <span class="h5tb-unit">Pa</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : Pressure increase</li><li style="list-style-type: none; font-style: italic">mean : 27.52554005504212</li><li style="list-style-type: none; font-style: italic">std : 0.28133467878082613</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/operation_point/vfr-4782055000" class="h5tb-var-list">
#                 <input id="ds-2-/operation_point/vfr-4782058600" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/operation_point/vfr-4782058600">vfr</label>
#                 <span class="h5tb-dims">(100,)</span>  [
#                 <span class="h5tb-unit">m^3/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : volume flow_utils rate</li><li style="list-style-type: none; font-style: italic">mean : 0.1009871986232441</li><li style="list-style-type: none; font-style: italic">std : 0.29115976991294856</li>
#
#                 </ul>
#
#              </ul>
#
# </li>
# </ul>
# </li>
# </ul>
# </div>
