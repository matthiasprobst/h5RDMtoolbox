# %% [markdown]
# # HDF5 and RDF - A linked-data approach
#
# HDF5 can be described semantically. Here's how:

# %%
import h5rdmtoolbox as h5tbx

# %%
with h5tbx.File() as h5:
    h5.attrs['title'] = 'Test file'
    
    h5.rdf['title'].definition = 'Title describes the content of the file'

    h5.attrs['name', 'https://schema.org/name'] = 'name'
    h5.dump()
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }
#
#
# /* Tooltip container */
# .tooltip {
# position: relative;
# display: inline-block;
# cursor: pointer;
# }
#
# /* Tooltip text */
# .tooltip .tooltiptext {
# visibility: hidden;
# width: 300px;
# background-color: #555;
# color: #fff;
# text-align: center;
# border-radius: 6px;
# padding: 5px;
# position: absolute;
# z-index: 1;
# bottom: 125%;
# left: 50%;
# margin-left: -60px;
# opacity: 0;
# transition: opacity 0.3s;
# }
#
# /* Show the tooltip on hover */
# .tooltip:hover .tooltiptext {
# visibility: visible;
# opacity:  1;
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--22119338588500" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--22119338588500">
#                         /<span>(0)</span></label>
#
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">name<a href="https://schema.org/name" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/iri_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">https://schema.org/name</span></a>: name</li><li style="list-style-type: none; font-style: italic">title<div class="tooltip"><img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/def_icon.png?raw=true" alt="D" width="16" height="16" /><span class="tooltiptext">Title describes the content of the file</span></div>: Test file</li>
#                     </ul>
# </li>
# </ul>
# </div>

# %%
with h5tbx.File(mode='w') as h5:
    grp = h5.create_group('contact',
                          attrs=dict(orcid='https://orcid.org/0000-0001-8729-0482'))   
    grp.rdf.predicate = 'https://schema.org/author'
    grp.rdf.type = 'http://xmlns.com/foaf/0.1/Person'
    grp.rdf.subject = 'https://orcid.org/0000-0001-8729-0482'
    grp.rdf.predicate['orcid'] =  'http://w3id.org/nfdi4ing/metadata4ing#orcidId'
    grp.attrs['name', 'http://xmlns.com/foaf/0.1/firstName'] = 'Matthias'

    o = grp.rdf.predicate['orcid']
    
    h5.dump(collapsed=False)

hdf_filename = h5.hdf_filename
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }
#
#
# /* Tooltip container */
# .tooltip {
# position: relative;
# display: inline-block;
# cursor: pointer;
# }
#
# /* Tooltip text */
# .tooltip .tooltiptext {
# visibility: hidden;
# width: 300px;
# background-color: #555;
# color: #fff;
# text-align: center;
# border-radius: 6px;
# padding: 5px;
# position: absolute;
# z-index: 1;
# bottom: 125%;
# left: 50%;
# margin-left: -60px;
# opacity: 0;
# transition: opacity 0.3s;
# }
#
# /* Show the tooltip on hover */
# .tooltip:hover .tooltiptext {
# visibility: visible;
# opacity:  1;
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--22142476962600" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--22142476962600">
#                         /<span>(1)</span></label>
#
# <ul class="h5tb-attr-list">
#                     </ul>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds-contact-22142477343800" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds-contact-22142477343800">
#                         contact<a href="http://xmlns.com/foaf/0.1/Person" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/type_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">@type: http://xmlns.com/foaf/0.1/Person</span></a><a href="https://orcid.org/0000-0001-8729-0482" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/id_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">@id: https://orcid.org/0000-0001-8729-0482</span></a><a href="https://schema.org/author" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/iri_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">https://schema.org/author</span></a><span>(0)</span></label>
#
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">name<a href="http://xmlns.com/foaf/0.1/firstName" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/iri_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">http://xmlns.com/foaf/0.1/firstName</span></a>: Matthias</li><li style="list-style-type: none; font-style: italic">orcid<a href="http://w3id.org/nfdi4ing/metadata4ing#orcidId" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/iri_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">http://w3id.org/nfdi4ing/metadata4ing#orcidId</span></a>: <a href="https://orcid.org/0000-0001-8729-0482"><img alt="ORCID logo" src="https://info.orcid.org/wp-content/uploads/2019/11/orcid_16x16.png" width="16" height="16" />https://orcid.org/0000-0001-8729-0482</a></li>
#                     </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>

# %% [markdown]
# ## JSON-LD extraction

# %%
from h5rdmtoolbox import jsonld

# %%
jstr = h5tbx.dump_jsonld(
    hdf_filename,
    indent=2,
    context={'m4i': 'http://w3id.org/nfdi4ing/metadata4ing#',
             'foaf': 'http://xmlns.com/foaf/0.1/'},
    structural=True
)

# %%
print(jstr)
# Out:
# {
#   "@context": {
#     "foaf": "http://xmlns.com/foaf/0.1/",
#     "hdf5": "http://purl.allotrope.org/ontologies/hdf5/1.8#",
#     "m4i": "http://w3id.org/nfdi4ing/metadata4ing#",
#     "name": "http://xmlns.com/foaf/0.1/firstName",
#     "orcid": "http://w3id.org/nfdi4ing/metadata4ing#orcidId"
#   },
#   "@graph": [
#     {
#       "@id": "_:N156",
#       "@type": "hdf5:File",
#       "hdf5:rootGroup": {
#         "@id": "_:N155",
#         "@type": "hdf5:Group",
#         "hdf5:member": {
#           "@id": "https://orcid.org/0000-0001-8729-0482",
#           "@type": [
#             "hdf5:Group",
#             "foaf:Person"
#           ],
#           "hdf5:attribute": [
#             {
#               "@id": "_:N157",
#               "@type": "hdf5:Attribute",
#               "hdf5:name": "name",
#               "hdf5:value": "Matthias"
#             },
#             {
#               "@id": "_:N158",
#               "@type": "hdf5:Attribute",
#               "hdf5:name": "orcid",
#               "hdf5:value": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#anyURI",
#                 "@value": "https://orcid.org/0000-0001-8729-0482"
#               }
#             }
#           ],
#           "hdf5:name": "/contact",
#           "name": "Matthias",
#           "orcid": {
#             "@type": "http://www.w3.org/2001/XMLSchema#anyURI",
#             "@value": "https://orcid.org/0000-0001-8729-0482"
#           }
#         },
#         "hdf5:name": "/"
#       }
#     }
#   ]
# }

# %% [markdown]
# ## Find based on RDF triples:

# %%
with h5tbx.File('rdf_example.hdf') as h5:
    h5.dump()
    res = h5.rdf.find(rdf_type=FOAF.Person)
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }
#
#
# /* Tooltip container */
# .tooltip {
# position: relative;
# display: inline-block;
# cursor: pointer;
# }
#
# /* Tooltip text */
# .tooltip .tooltiptext {
# visibility: hidden;
# width: 300px;
# background-color: #555;
# color: #fff;
# text-align: center;
# border-radius: 6px;
# padding: 5px;
# position: absolute;
# z-index: 1;
# bottom: 125%;
# left: 50%;
# margin-left: -60px;
# opacity: 0;
# transition: opacity 0.3s;
# }
#
# /* Show the tooltip on hover */
# .tooltip:hover .tooltiptext {
# visibility: visible;
# opacity:  1;
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--22146070685300" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--22146070685300">
#                         /<span>(3)</span></label>
#
# <ul class="h5tb-attr-list">
#                     </ul>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds-contact-22146071370100" type="checkbox" >
#                         <label style="font-weight: bold" for="group-ds-contact-22146071370100">
#                         contact<a href="http://xmlns.com/foaf/0.1/Person" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/type_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">@type: http://xmlns.com/foaf/0.1/Person</span></a><a href="https://orcid.org/0000-0001-8729-0482" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/id_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">@id: https://orcid.org/0000-0001-8729-0482</span></a><a href="https://schema.org/author" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/iri_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">https://schema.org/author</span></a><span>(0)</span></label>
#
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">first_name<a href="http://xmlns.com/foaf/0.1/firstName" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/iri_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">http://xmlns.com/foaf/0.1/firstName</span></a>: Matthias</li><li style="list-style-type: none; font-style: italic">orcid<a href="http://w3id.org/nfdi4ing/metadata4ing#orcidId" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/iri_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">http://w3id.org/nfdi4ing/metadata4ing#orcidId</span></a>: <a href="https://orcid.org/0000-0001-8729-0482"><img alt="ORCID logo" src="https://info.orcid.org/wp-content/uploads/2019/11/orcid_16x16.png" width="16" height="16" />https://orcid.org/0000-0001-8729-0482</a></li>
#                     </ul>
# </li>
# </ul>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds-grp-22146072297000" type="checkbox" >
#                         <label style="font-weight: bold" for="group-ds-grp-22146072297000">
#                         grp<span>(1)</span></label>
#
# <ul class="h5tb-attr-list">
#                     </ul>
#
#                 <ul id="ds-1-/grp/random_velocity-22146073716500" class="h5tb-var-list">
#                     <input id="ds-2-/grp/random_velocity-22146073719400" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/grp/random_velocity-22146073719400">random_velocity</label>
#                     <span class="h5tb-dims">(100) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">quantity_kind<a href="http://w3id.org/nfdi4ing/metadata4ing#hasKindOfQuantity" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/iri_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">http://w3id.org/nfdi4ing/metadata4ing#hasKindOfQuantity</span></a>: velocity<a href="http://qudt.org/vocab/quantitykind/Velocity" target="_blank" class="tooltip"> <img class="size_of_img" src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev/h5rdmtoolbox/data/iri_icon.png?raw=true" alt="IRI_ICON" width="16" height="16" /> <span class="tooltiptext">http://qudt.org/vocab/quantitykind/Velocity</span></a></li><li style="list-style-type: none; font-style: italic">units<a href="http://w3id.org/nfdi4ing/metadata4ing#hasUnit" target="_bl

# %%
res
# Out:
# [<LGroup "/contact" in "rdf_example.hdf">]

# %%
print(
    h5tbx.dump_jsonld(
        hdf_filename,
        indent=2,
        context={'m4i': 'http://w3id.org/nfdi4ing/metadata4ing#',
                 'foaf': 'http://xmlns.com/foaf/0.1/'}
    )
)
# Out:
# {
#   "@context": {
#     "foaf": "http://xmlns.com/foaf/0.1/",
#     "hdf5": "http://purl.allotrope.org/ontologies/hdf5/1.8#",
#     "m4i": "http://w3id.org/nfdi4ing/metadata4ing#",
#     "name": "http://xmlns.com/foaf/0.1/firstName",
#     "orcid": "http://w3id.org/nfdi4ing/metadata4ing#orcidId"
#   },
#   "@graph": [
#     {
#       "@id": "_:N160",
#       "@type": "hdf5:File",
#       "hdf5:rootGroup": {
#         "@id": "_:N159",
#         "@type": "hdf5:Group",
#         "hdf5:member": {
#           "@id": "https://orcid.org/0000-0001-8729-0482",
#           "@type": [
#             "hdf5:Group",
#             "foaf:Person"
#           ],
#           "hdf5:attribute": [
#             {
#               "@id": "_:N161",
#               "@type": "hdf5:Attribute",
#               "hdf5:name": "name",
#               "hdf5:value": "Matthias"
#             },
#             {
#               "@id": "_:N162",
#               "@type": "hdf5:Attribute",
#               "hdf5:name": "orcid",
#               "hdf5:value": {
#                 "@type": "http://www.w3.org/2001/XMLSchema#anyURI",
#                 "@value": "https://orcid.org/0000-0001-8729-0482"
#               }
#             }
#           ],
#           "hdf5:name": "/contact",
#           "name": "Matthias",
#           "orcid": {
#             "@type": "http://www.w3.org/2001/XMLSchema#anyURI",
#             "@value": "https://orcid.org/0000-0001-8729-0482"
#           }
#         },
#         "hdf5:name": "/"
#       }
#     }
#   ]
# }

# %%
with h5tbx.File('rdf_example.hdf') as h5:
    js = h5.dump_jsonld(context={'m4i': 'http://w3id.org/nfdi4ing/metadata4ing#', 'foaf': 'http://xmlns.com/foaf/0.1/'})

# %%
with open('rdf_example.json', mode='w') as f:
    f.write(js)

# %% [markdown]
# ## Query with sparql

# %%
import rdflib.graph as g

graph = g.Graph()
graph.parse('rdf_example.json', format='json-ld')
# Out:
# <Graph identifier=Nc9bf0c1900b7490a83d77ec00b237c2a (<class 'rdflib.graph.Graph'>)>

# %%
res = graph.query("""
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX m4i: <http://w3id.org/nfdi4ing/metadata4ing#>

SELECT ?id ?name
WHERE {
    # ?id a foaf:Person .
    # ?id foaf:firstName ?name .
    }
""")

# %%
for r in res:
    print(r)
# Out:
# (rdflib.term.URIRef('https://orcid.org/0000-0001-8729-0482'), rdflib.term.Literal('Matthias'))

# %%
res = graph.query("""
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX hdf5: <http://purl.allotrope.org/ontologies/hdf5/1.8#>

SELECT ?id ?name
WHERE {
    # ?id a hdf5:Group .
    # ?id hdf5:name ?name .
    }
""")

# %%
for r in res:
    print(r)
# Out:
# (rdflib.term.BNode('N163'), rdflib.term.Literal('/'))
# (rdflib.term.URIRef('https://orcid.org/0000-0001-8729-0482'), rdflib.term.Literal('/contact'))
# (rdflib.term.BNode('N167'), rdflib.term.Literal('/grp'))
# (rdflib.term.BNode('N171'), rdflib.term.Literal('/processing_info'))

# %%
res = graph.query("""
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX hdf5: <http://purl.allotrope.org/ontologies/hdf5/1.8#>

SELECT ?id ?name
WHERE {
    # ?id a hdf5:Dataset .
    # ?id hdf5:name ?name .
    }
""")

# %%
for r in res:
    print(r)
# Out:
# (rdflib.term.BNode('N168'), rdflib.term.Literal('/grp/random_velocity'))

# %% [markdown]
# ## Visualization

# %%
import kglab

# %%
g, ctx = h5tbx.jsonld.get_rdflib_graph('rdf_example.hdf')

# %%
kg = kglab.KnowledgeGraph(
    import_graph=g,
    namespaces=ctx)

# %%
subgraph = kglab.SubgraphTensor(kg)
VIS_STYLE= {"hdf5": {"color": "red", "size": 30},
            "_": {"color": "black", "size": 20}}

# %%
pyvis_graph= subgraph.build_pyvis_graph(notebook=True, style=VIS_STYLE)
pyvis_graph.show('graph.html', notebook=True)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# graph.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
