# %% [markdown]
# # Using Ontologies with HDF5/Usage of IRI
#
# Currently, the `h5rdmtoolbox` supports the usage of international resource identifiers (IRI) as used with ontologies.
#
# An *IRI* can be assigned to attribute names and/or data.
#
# In the following example, we create an HDF5 file and assign certain metadata to the root group and a dataset. For some of the metadata we know, that it is defined by an ontology:
# - contact_person: http://w3id.org/nfdi4ing/metadata4ing#ContactPerson
# - creator: http://w3id.org/nfdi4ing/metadata4ing#DataCollector
# - units: https://qudt.org/schema/qudt/Unit
#
# The attribute data for the roles "contact" and "creator" are *ORCID IDs*. This is something, which is also defined by the m4i (metadata4ing) ontology: http://w3id.org/nfdi4ing/metadata4ing#orcidId.
#
# The below code shows how we can assign those IRIs to the attribute names and data, respectively. The syntax is mimicking the syntax of the `h5py.AttributeManager`:

# %%
import h5rdmtoolbox as h5tbx

# %%
with h5tbx.File(attrs={'title': 'test file'}) as h5:
    h5.attrs['contact_person'] = h5tbx.__author_orcid__
    h5.create_dataset('vel', data=[1,2,3], attrs={'units': 'm/s',
                                                  'creator': h5tbx.__author_orcid__,
                                                 'long_name': 'my velocity dataset'})
    h5.vel.attrs.create('random_attr', data=1)
    h5.iri['contact_person'].name = 'http://w3id.org/nfdi4ing/metadata4ing#ContactPerson'
    h5.iri['contact_person'].dat = 'http://w3id.org/nfdi4ing/metadata4ing#orcidId'
    h5.vel.iri['units'].name = 'https://qudt.org/schema/qudt/Unit'
    h5.vel.iri['creator'].name = 'http://w3id.org/nfdi4ing/metadata4ing#DataCollector'
    h5.vel.iri['creator'].data = 'http://w3id.org/nfdi4ing/metadata4ing#orcidId'

# %% [markdown]
# By associating the attribute names and/or data to *IRI*s we not only describe the metadata with persistent identifiers to be used by another software, the HTML-representation of the file content now also presents the *IRI*-icon. Clicking on it will open the link:

# %%
h5tbx.dump(h5.hdf_filename, collapsed=False)
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--75960529258400" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--75960529258400">
#                         /<span>(1)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.13.0</li><li style="list-style-type: none; font-style: italic">contact_person<a href="http://w3id.org/nfdi4ing/metadata4ing#ContactPerson"><img src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev-PIDattr/h5rdmtoolbox/data/iri_icon.png?raw=true" alt=" [IRI]" width="16" height="16" /></a> : <a href="https://orcid.org/0000-0001-8729-0482"><img alt="ORCID logo" src="https://info.orcid.org/wp-content/uploads/2019/11/orcid_16x16.png" width="16" height="16" />https://orcid.org/0000-0001-8729-0482</a></li><li style="list-style-type: none; font-style: italic">title : test file</li>
#                     </ul>
#
#                 <ul id="ds-1-/vel-75960530580100" class="h5tb-var-list">
#                     <input id="ds-2-/vel-75960530583700" class="h5tb-varname-in" type="checkbox" checked>
#                     <label class='h5tb-varname' for="ds-2-/vel-75960530583700">vel</label>
#                     <span class="h5tb-dims">(3) [int32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">creator<a href="http://w3id.org/nfdi4ing/metadata4ing#DataCollector"><img src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev-PIDattr/h5rdmtoolbox/data/iri_icon.png?raw=true" alt=" [IRI]" width="16" height="16" /></a> : <a href="https://orcid.org/0000-0001-8729-0482"><img alt="ORCID logo" src="https://info.orcid.org/wp-content/uploads/2019/11/orcid_16x16.png" width="16" height="16" />https://orcid.org/0000-0001-8729-0482</a><a href="http://w3id.org/nfdi4ing/metadata4ing#orcidId"><img src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev-PIDattr/h5rdmtoolbox/data/iri_icon.png?raw=true" alt=" [IRI]" width="16" height="16" /></a></li><li style="list-style-type: none; font-style: italic">long_name : my velocity dataset</li><li style="list-style-type: none; font-style: italic">random_attr : 1</li><li style="list-style-type: none; font-style: italic">units<a href="https://qudt.org/schema/qudt/Unit"><img src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev-PIDattr/h5rdmtoolbox/data/iri_icon.png?raw=true" alt=" [IRI]" width="16" height="16" /></a> : m/s</li>
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </div>

# %% [markdown]
# **Removing** an attribute will not remove the associated *IRI*. The `del` call need to be performed on both objects:

# %%
with h5tbx.File(h5.hdf_filename, 'r+') as h5:
    del h5.vel.attrs['creator']
    del h5.vel.iri['creator']
    h5.dump(collapsed=False)
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--75502167402900" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--75502167402900">
#                         /<span>(1)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.13.0</li><li style="list-style-type: none; font-style: italic">contact_person<a href="http://w3id.org/nfdi4ing/metadata4ing#ContactPerson"><img src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev-PIDattr/h5rdmtoolbox/data/iri_icon.png?raw=true" alt=" [IRI]" width="16" height="16" /></a> : <a href="https://orcid.org/0000-0001-8729-0482"><img alt="ORCID logo" src="https://info.orcid.org/wp-content/uploads/2019/11/orcid_16x16.png" width="16" height="16" />https://orcid.org/0000-0001-8729-0482</a></li><li style="list-style-type: none; font-style: italic">title : test file</li>
#                     </ul>
#
#                 <ul id="ds-1-/vel-75502168540900" class="h5tb-var-list">
#                     <input id="ds-2-/vel-75502168545200" class="h5tb-varname-in" type="checkbox" checked>
#                     <label class='h5tb-varname' for="ds-2-/vel-75502168545200">vel</label>
#                     <span class="h5tb-dims">(3) [int32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : my velocity dataset</li><li style="list-style-type: none; font-style: italic">random_attr : 1</li><li style="list-style-type: none; font-style: italic">units<a href="https://qudt.org/schema/qudt/Unit"><img src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev-PIDattr/h5rdmtoolbox/data/iri_icon.png?raw=true" alt=" [IRI]" width="16" height="16" /></a> : m/s<a href="https://qudt.org/schema/qudt/Unit"><img src="https://github.com/matthiasprobst/h5RDMtoolbox/blob/dev-PIDattr/h5rdmtoolbox/data/iri_icon.png?raw=true" alt=" [IRI]" width="16" height="16" /></a></li>
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </div>
