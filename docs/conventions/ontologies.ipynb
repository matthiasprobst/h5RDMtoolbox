# %% [markdown]
# # Using Ontologies with HDF5/Usage of IRI
#
# Currently the `h5rdmtoolbox` supports the usage of `IRI` (international resource identifier) as used with ontologies.
#
# An `IRI` can be assigned together with attribute assignment and clearly describes it, so that users and machines can understand the meaning of it.
#
# The following examples uses `units` and `creator` as attributes of a dataset. In order to explain these meta information, `IRI`s are associated with them by using the `iri`-property.

# %%
import h5rdmtoolbox as h5tbx

# %%
with h5tbx.File() as h5:
    h5.create_dataset('vel', data=[1,2,3], attrs={'units': 'm/s',
                                                  'creator': h5tbx.__author_orcid__,
                                                 'long_name': 'my velocity dataset'})
    h5.vel.iri['units'] = 'https://qudt.org/schema/qudt/Unit'
    h5.vel.iri['creator'] = 'http://w3id.org/nfdi4ing/metadata4ing#ContactPerson'

# %% [markdown]
# **Note the changed representation**, which we get when dumping the file to screen. The attribute names, that are associated with a `IRI`s got hyperlinks:

# %%
h5tbx.dump(h5.hdf_filename, collapsed=False)
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--172422077300" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--172422077300">
#                         /<span>(1)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.13.0</li>
#                     </ul>
#
#                 <ul id="ds-1-/vel-172424025700" class="h5tb-var-list">
#                     <input id="ds-2-/vel-172424034500" class="h5tb-varname-in" type="checkbox" checked>
#                     <label class='h5tb-varname' for="ds-2-/vel-172424034500">vel</label>
#                     <span class="h5tb-dims">(3) [int32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic"><a href="http://w3id.org/nfdi4ing/metadata4ing#ContactPerson">creator</a> : <a href="https://orcid.org/0000-0001-8729-0482"><img alt="ORCID logo" src="https://info.orcid.org/wp-content/uploads/2019/11/orcid_16x16.png" width="16" height="16" />https://orcid.org/0000-0001-8729-0482</a></li><li style="list-style-type: none; font-style: italic">long_name : my velocity dataset</li><li style="list-style-type: none; font-style: italic"><a href="https://qudt.org/schema/qudt/Unit">units</a> : m/s</li>
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </div>

# %% [markdown]
# Adding attributes simultaneously with attributes is also possible. For this, we need a helper class, called `h5tbx.iri.IRI`:

# %%
with h5tbx.File() as h5:
    h5.create_dataset('vel', data=[1,2,3],
                      attrs={'units': h5tbx.iri.IRI('m/s', 'https://qudt.org/schema/qudt/Unit'),
                             'creator': h5tbx.iri.IRI(h5tbx.__author_orcid__, 'http://w3id.org/nfdi4ing/metadata4ing#ContactPerson'),
                             'long_name': 'my velocity dataset'})
    h5.dump(collapsed=False)
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--421293408700" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--421293408700">
#                         /<span>(1)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.13.0</li>
#                     </ul>
#
#                 <ul id="ds-1-/vel-421295597300" class="h5tb-var-list">
#                     <input id="ds-2-/vel-421295606900" class="h5tb-varname-in" type="checkbox" checked>
#                     <label class='h5tb-varname' for="ds-2-/vel-421295606900">vel</label>
#                     <span class="h5tb-dims">(3) [int32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic"><a href="http://w3id.org/nfdi4ing/metadata4ing#ContactPerson">creator</a> : <a href="https://orcid.org/0000-0001-8729-0482"><img alt="ORCID logo" src="https://info.orcid.org/wp-content/uploads/2019/11/orcid_16x16.png" width="16" height="16" />https://orcid.org/0000-0001-8729-0482</a></li><li style="list-style-type: none; font-style: italic">long_name : my velocity dataset</li><li style="list-style-type: none; font-style: italic"><a href="https://qudt.org/schema/qudt/Unit">units</a> : m/s</li>
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </div>
