# %% [markdown]
# # ... slice a dataset based on a condition?
# Good practice is to have dimension attached to the datasets. The dimension scales can be used to decide what to slice exactly. The following example first generates a dataset and the slices it depending on the value in the first dimension, in this case the time:

# %%
import h5rdmtoolbox as h5tbx
import numpy as np

h5tbx.use(None)

with h5tbx.File() as h5:
    h5.create_dataset('time', data=range(0, 100), make_scale=True)
    h5.create_dataset('x', data=range(0, 100), make_scale=True)
    h5.create_dataset('y', data=range(0, 200), make_scale=True)
    h5.create_dataset('data', np.random.rand(100, 200, 100), attach_scale=('time', 'y', 'x'))
    data = h5.data[:]
    h5.dump()
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: rgba(0,0,0,.0);
#     padding-bottom: 6px;
#     color: #6a6c73;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: rgba(0,0,0,.0);
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--5899890300" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--5899890300">
#                         /<span>(4)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 1.0.0</li>
#                     </ul>
#
#                 <ul id="ds-1-/data-5902428100" class="h5tb-var-list">
#                     <input id="ds-2-/data-5902433100" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/data-5902433100">data</label>
#                     <span class="h5tb-dims">(time: 100, y: 200, x: 100) [float64]</span>
#                 <ul class="h5tb-attr-list">
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/time-5902659500" class="h5tb-var-list">
#                     <input id="ds-2-/time-5902663200" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/time-5902663200">time</label>
#                     <span class="h5tb-dims">(100) [int32]</span>
#                 <ul class="h5tb-attr-list">
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/x-5902852800" class="h5tb-var-list">
#                     <input id="ds-2-/x-5902856900" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/x-5902856900">x</label>
#                     <span class="h5tb-dims">(100) [int32]</span>
#                 <ul class="h5tb-attr-list">
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/y-5903001800" class="h5tb-var-list">
#                     <input id="ds-2-/y-5903005600" class="h5tb-varname-in" type="checkbox" >
#                     <label class='h5tb-varname' for="ds-2-/y-5903005600">y</label>
#                     <span class="h5tb-dims">(200) [int32]</span>
#                 <ul class="h5tb-attr-list">
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </div>

# %%
with h5tbx.File(h5.hdf_filename) as h5:
    h5.data[h5.data.time > 5.4, :, :].plot()
