# %% [markdown]
# # CF-like
#
# The cf-conventions ([cfconventions.org]) promote the usage of specific attributes in order to fully describe a variable (dataset). The `h5rdmtoolbox` at this stage implements the CF convention in a very simlar way. As it is probably not the 100% equivilant yet, we call the convention `cflike`.
#
# The convention can be switched durng runtime. The default convention (means using no convention) is `default`, to switch to the CF-like call `use('cflike')`:
#
# [cfconventions.org]: http://cfconventions.org/

# %%
import h5rdmtoolbox as h5tbx
h5tbx.use('cflike', force=True)
# Out:
# 2022-10-24_16:30:30,765 INFO     [__init__.py:40] Switched to cflike

# %% [markdown]
# Let's check the `__str__()` method. It should tell which convention is used:

# %%
h5 = h5tbx.H5File()
print(h5)
h5.close()
# Out:
# <class 'h5rdmtoolbox.H5File' convention: cflike>

# %% [markdown]
# ## Working with HDF5 files following the cf-like convention
#
# Some attributes are obligatory to provide with a dataset:
# - `units`
# - `standard_name`
# - `long_name` (not needed if `standard_name` exists and vise versa)
#
# **units**<br>
# We expect that each data set written to the HDF5 file has a physical unit or no unit at all. It is registered in the attribute `units`.
#
# **standard_name and long_name**<br>
# For the sake of improved readability and interpretability we suggest to use `long_name` or `standard_name` as additional attributes. While `long_name` is human-readable and interpretable attribute, `standard_name` is intended to be read by a machine (other software). This allows to automate exploration and processing work.
#
# The `standard_name` generally should not be chosen freely but must follow a certain convention. Such a naming convention may be defined by a project or a community, e.g. the climate and forecast community [cfconventions.org], from which the concept of standard names is adoped. A convention is described in an **XML** file and associated with the wrapper file `H5File`. Again this is adoped from [cfconventions.org]. The XML file contains the standard name, a description for each one and the respective unit. Thus, if a convention is associated with a wrapper class, the standard name and unit cannot be freely be chsen but is verified.

# %%
with h5tbx.H5File(title='MyFile') as h5:
    ds = h5.create_dataset('velocity', data=4.3, units='m/s', standard_name='x_velocity')
    print(ds)
    h5.create_group('testgrp', long_name='my test group')
    sn = ds.standard_name
    h5.dump()
# Out:
# <HDF5 dataset "velocity": shape (), type "<f8", convention "cflike">
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
#
# .h5tb-unit {
#     width: 96px;
#     white-space: nowrap;
#     padding-right: 2px;
#     text-align: right;
#     color: #555;
#     font-style: italic;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: #fff;
#     padding-bottom: 6px;
#     color: #555;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: #fff;
# }
#
# .h5tb-dim-highlight {
#     background-color: rgba(3, 169, 244, .2);
#     cursor: pointer;
# }</style></head>
# <p>tmp23.hdf</p>
#
# <div class='h5tb-warp'>
#
#           <ul style="list-style-type: none;" class="h5grp-sections">
#                 <li>
#                     <input id="group-ds-/-610697973000" type="checkbox" checked>
#                     <label style="font-weight: bold" for="group-ds-/-610697973000">
#                     /<span>(2)</span></label>
#
#
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.2.0</li><li style="list-style-type: none; font-style: italic">__wrcls__ : H5File</li><li style="list-style-type: none; font-style: italic">title : MyFile</li>
#                 </ul>
#
#                     <ul id="ds-1-/velocity-610698741700" class="h5tb-var-list">
#                     <input id="ds-2-/velocity-610698744000" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname'
#                         for="ds-2-/velocity-610698744000">velocity</label>
#                     <span class="h5tb-dims"></span>  [
#                     <span class="h5tb-unit">m/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style:
#          italic">standard_name : x_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#           <ul style="list-style-type: none;" class="h5grp-sections">
#                 <li>
#                     <input id="group-ds-/testgrp-610698843600" type="checkbox" >
#                     <label style="font-weight: bold" for="group-ds-/testgrp-610698843600">
#                     testgrp<span>(0)</span></label>
#
#
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : my test group</li>
#                 </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>

# %%
sn
# Out:
# StandardName(name='x_velocity', description=None, canonical_units=None, snt=EmptyStandardNameTable (version number: 0))
