# %% [markdown]
# # Specialized Wrappers
#
# By inheriting the main wrapper class `H5File` domain-specific functionality can be added. Although properties can be registered, it can be worth the effort of inheriting the class to permanently add features to it.
#
# The package provides two such class:
#  - `H5Flow` and
#  - `H5PIV`
#
# ---

# %% [markdown]
# ## H5Flow
#
# To enhance the work with fluid-related HDF5 datasts, `H5Flow` is implemented, which is inherited from `H5File`. Thus, all features plus the domain specific one, that will be outlined here, are available.
#
# For fluid data, we expect the file to have certain datasets, that are coordinates and velocities. Most likely other derived datasets may exist like gradients or other physical measured or simulated variables like pressure, for instance.

# %%
import numpy as np
import h5rdmtoolbox as h5tbx

# %%
with h5tbx.H5Flow() as h5:
    filename = h5.hdf_filename  # keep for later use
    h5.create_coordinates(x=np.linspace(0, 1, 20),
                          y=np.linspace(0, 0.5, 10),
                          z=np.linspace(-1, 1, 3),
                          coords_unit='mm')
    h5.create_velocity_datasets(u=np.random.rand(3, 10, 20),
                                v=np.random.rand(3, 10, 20),
                                w=np.random.rand(3, 10, 20),
                                dim_scales=('z', 'y', 'x'),
                                units='mm/s')
    h5.dump()
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
#
# .h5tb-unit {
#     width: 96px;
#     white-space: nowrap;
#     padding-right: 2px;
#     text-align: right;
#     color: #555;
#     font-style: italic;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: #fff;
#     padding-bottom: 6px;
#     color: #555;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: #fff;
# }
#
# .h5tb-dim-highlight {
#     background-color: rgba(3, 169, 244, .2);
#     cursor: pointer;
# }</style></head>
# <p>tmp0.hdf</p>
# <p>Check resuted in 1 issues.</p>
#
# <div class='h5tb-warp'>
#
#           <ul style="list-style-type: none;" class="h5grp-sections">
#                 <li>
#                     <input id="group-ds-/-3419835000" type="checkbox" checked>
#                     <label style="font-weight: bold" for="group-ds-/-3419835000">
#                     /<span>(7)</span></label>
#
#
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.1.0</li><li style="list-style-type: none; font-style: italic">__standard_name_table__ : fluid-v1</li><li style="list-style-type: none; font-style: italic">__wrcls__ : H5Flow</li>
#                 </ul>
#
#                 <ul id="ds-1-/time-3421118400" class="h5tb-var-list">
#                 <input id="ds-2-/time-3421120700" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/time-3421120700">time</label>
#                 <span class="h5tb-dims"></span>  [
#                 <span class="h5tb-unit">s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : time</li><li style="list-style-type: none; font-style:
#          italic">standard_name : time</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/u-3421631000" class="h5tb-var-list">
#                 <input id="ds-2-/u-3421633200" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/u-3421633200">u</label>
#                 <span class="h5tb-dims">(z: 3, y: 10, x: 20)</span>  [
#                 <span class="h5tb-unit">mm/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style:
#          italic">standard_name : x_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/v-3422197900" class="h5tb-var-list">
#                 <input id="ds-2-/v-3422200000" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/v-3422200000">v</label>
#                 <span class="h5tb-dims">(z: 3, y: 10, x: 20)</span>  [
#                 <span class="h5tb-unit">mm/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style:
#          italic">standard_name : y_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/w-3422641900" class="h5tb-var-list">
#                 <input id="ds-2-/w-3422643900" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/w-3422643900">w</label>
#                 <span class="h5tb-dims">(z: 3, y: 10, x: 20)</span>  [
#                 <span class="h5tb-unit">mm/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style:
#          italic">standard_name : z_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/x-3422886900" class="h5tb-var-list">
#                 <input id="ds-2-/x-3422888900" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/x-3422888900">x</label>
#                 <span class="h5tb-dims">(20,)</span>  [
#                 <span class="h5tb-unit">mm</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : x</li><li style="list-style-type: none; font-style:
#          italic">standard_name : x_coordinate</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/y-3423237100" class="h5tb-var-list">
#                 <input id="ds-2-/y-3423239300" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/y-3423239300">y</label>
#                 <span class="h5tb-dims">(10,)</span>  [
#                 <span class="h5tb-unit">mm</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : y</li><li style="list-style-type: none; font-style:
#          italic">standard_name : y_coordinate</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/z-3423558600" class="h5tb-var-list">
#                 <input id="ds-2-/z-3423560600" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/z-3423560600">z</label>
#                 <span class="h5tb-dims">(3,)</span>  [
#                 <span class="h5tb-unit">mm</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : z</li><li style="list-style-type: none; font-style:
#          italic">standard_name : z_coordinate</li>

# %% [markdown]
# ## Accessing vector data
#
# Fluid data holds vector variables, like coordinates, velocities, gradients and more. To access them, the property `Vector` can be called. As it is generally unknown, which HDF datasets belong to a vector, we need to specify them like so:

# %%
with h5tbx.H5Flow(filename) as h5:
    vel = h5.Vector(names=('u', 'v', 'w'))[0:1, :, :]
vel
# Out:
# <div><svg style="position: absolute; width: 0; height: 0; overflow: hidden">
# <defs>
# <symbol id="icon-database" viewBox="0 0 32 32">
# <path d="M16 0c-8.837 0-16 2.239-16 5v4c0 2.761 7.163 5 16 5s16-2.239 16-5v-4c0-2.761-7.163-5-16-5z"></path>
# <path d="M16 17c-8.837 0-16-2.239-16-5v6c0 2.761 7.163 5 16 5s16-2.239 16-5v-6c0 2.761-7.163 5-16 5z"></path>
# <path d="M16 26c-8.837 0-16-2.239-16-5v6c0 2.761 7.163 5 16 5s16-2.239 16-5v-6c0 2.761-7.163 5-16 5z"></path>
# </symbol>
# <symbol id="icon-file-text2" viewBox="0 0 32 32">
# <path d="M28.681 7.159c-0.694-0.947-1.662-2.053-2.724-3.116s-2.169-2.030-3.116-2.724c-1.612-1.182-2.393-1.319-2.841-1.319h-15.5c-1.378 0-2.5 1.121-2.5 2.5v27c0 1.378 1.122 2.5 2.5 2.5h23c1.378 0 2.5-1.122 2.5-2.5v-19.5c0-0.448-0.137-1.23-1.319-2.841zM24.543 5.457c0.959 0.959 1.712 1.825 2.268 2.543h-4.811v-4.811c0.718 0.556 1.584 1.309 2.543 2.268zM28 29.5c0 0.271-0.229 0.5-0.5 0.5h-23c-0.271 0-0.5-0.229-0.5-0.5v-27c0-0.271 0.229-0.5 0.5-0.5 0 0 15.499-0 15.5 0v7c0 0.552 0.448 1 1 1h7v19.5z"></path>
# <path d="M23 26h-14c-0.552 0-1-0.448-1-1s0.448-1 1-1h14c0.552 0 1 0.448 1 1s-0.448 1-1 1z"></path>
# <path d="M23 22h-14c-0.552 0-1-0.448-1-1s0.448-1 1-1h14c0.552 0 1 0.448 1 1s-0.448 1-1 1z"></path>
# <path d="M23 18h-14c-0.552 0-1-0.448-1-1s0.448-1 1-1h14c0.552 0 1 0.448 1 1s-0.448 1-1 1z"></path>
# </symbol>
# </defs>
# </svg>
# <style>/* CSS stylesheet for displaying xarray objects in jupyterlab.
#  *
#  */
#
# :root {
#   --xr-font-color0: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --xr-font-color2: var(--jp-content-font-color2, rgba(0, 0, 0, 0.54));
#   --xr-font-color3: var(--jp-content-font-color3, rgba(0, 0, 0, 0.38));
#   --xr-border-color: var(--jp-border-color2, #e0e0e0);
#   --xr-disabled-color: var(--jp-layout-color3, #bdbdbd);
#   --xr-background-color: var(--jp-layout-color0, white);
#   --xr-background-color-row-even: var(--jp-layout-color1, white);
#   --xr-background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme=dark],
# body[data-theme=dark],
# body.vscode-dark {
#   --xr-font-color0: rgba(255, 255, 255, 1);
#   --xr-font-color2: rgba(255, 255, 255, 0.54);
#   --xr-font-color3: rgba(255, 255, 255, 0.38);
#   --xr-border-color: #1F1F1F;
#   --xr-disabled-color: #515151;
#   --xr-background-color: #111111;
#   --xr-background-color-row-even: #111111;
#   --xr-background-color-row-odd: #313131;
# }
#
# .xr-wrap {
#   display: block !important;
#   min-width: 300px;
#   max-width: 700px;
# }
#
# .xr-text-repr-fallback {
#   /* fallback to plain text repr when CSS is not injected (untrusted notebook) */
#   display: none;
# }
#
# .xr-header {
#   padding-top: 6px;
#   padding-bottom: 6px;
#   margin-bottom: 4px;
#   border-bottom: solid 1px var(--xr-border-color);
# }
#
# .xr-header > div,
# .xr-header > ul {
#   display: inline;
#   margin-top: 0;
#   margin-bottom: 0;
# }
#
# .xr-obj-type,
# .xr-array-name {
#   margin-left: 2px;
#   margin-right: 10px;
# }
#
# .xr-obj-type {
#   color: var(--xr-font-color2);
# }
#
# .xr-sections {
#   padding-left: 0 !important;
#   display: grid;
#   grid-template-columns: 150px auto auto 1fr 20px 20px;
# }
#
# .xr-section-item {
#   display: contents;
# }
#
# .xr-section-item input {
#   display: none;
# }
#
# .xr-section-item input + label {
#   color: var(--xr-disabled-color);
# }
#
# .xr-section-item input:enabled + label {
#   cursor: pointer;
#   color: var(--xr-font-color2);
# }
#
# .xr-section-item input:enabled + label:hover {
#   color: var(--xr-font-color0);
# }
#
# .xr-section-summary {
#   grid-column: 1;
#   color: var(--xr-font-color2);
#   font-weight: 500;
# }
#
# .xr-section-summary > span {
#   display: inline-block;
#   padding-left: 0.5em;
# }
#
# .xr-section-summary-in:disabled + label {
#   color: var(--xr-font-color2);
# }
#
# .xr-section-summary-in + label:before {
#   display: inline-block;
#   content: '►';
#   font-size: 11px;
#   width: 15px;
#   text-align: center;
# }
#
# .xr-section-summary-in:disabled + label:before {
#   color: var(--xr-disabled-color);
# }
#
# .xr-section-summary-in:checked + label:before {
#   content: '▼';
# }
#
# .xr-section-summary-in:checked + label > span {
#   display: none;
# }
#
# .xr-section-summary,
# .xr-section-inline-details {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# .xr-section-inline-details {
#   grid-column: 2 / -1;
# }
#
# .xr-section-details {
#   display: none;
#   grid-column: 1 / -1;
#   margin-bottom: 5px;
# }
#
# .xr-section-summary-in:checked ~ .xr-section-details {
#   display: contents;
# }
#
# .xr-array-wrap {
#   grid-column: 1 / -1;
#   display: grid;
#   grid-template-columns: 20px auto;
# }
#
# .xr-array-wrap > label {
#   grid-column: 1;
#   vertical-align: top;
# }
#
# .xr-preview {
#   color: var(--xr-font-color3);
# }
#
# .xr-array-preview,
# .xr-array-data {
#   padding: 0 5px !important;
#   grid-column: 2;
# }
#
# .xr-array-data,
# .xr-array-in:checked ~ .xr-array-preview {
#   display: none;
# }
#
# .xr-array-in:checked ~ .xr-array-data,
# .xr-array-preview {
#   display: inline-block;
# }
#
# .xr-dim-list {
#   display: inline-block !important;
#   list-style: none;
#   padding: 0 !important;
#   margin: 0;
# }
#
# .xr-dim-list li {
#   display: inline-block;
#   padding: 0;
#   margin: 0;
# }
#
# .xr-dim-list:before {
#   content: '(';
# }
#
# .xr-dim-list:after {
#   content: ')';
# }
#
# .xr-dim-list li:not(:last-child):after {
#   content: ',';
#   padding-right: 5px;
# }
#
# .xr-has-index {
#   font-weight: bold;
# }
#
# .xr-var-list,
# .xr-var-item {
#   display: contents;
# }
#
# .xr-var-item > div,
# .xr-var-item label,
# .xr-var-item > .xr-var-name span {
#   background-color: var(--xr-background-color-row-even);
#   margin-bottom: 0;
# }
#
# .xr-var-item > .xr-var-name:hover span {
#   padding-right: 5px;
# }
#
# .xr-var-list > li:nth-child(odd) > div,
# .xr-var-list > li:nth-child(odd) > label,
# .xr-var-list > li:nth-child(odd) > .xr-var-name span {
#   background-color: var(--xr-background-color-row-odd);
# }
#
# .xr-var-name {
#   grid-column: 1;
# }
#
# .xr-var-dims {
#   grid-column: 2;
# }
#
# .xr-var-dtype {
#   grid-column: 3;
#   text-align: right;
#   color: var(--xr-font-color2);
# }
#
# .xr-var-preview {
#   grid-column: 4;
# }
#
# .xr-var-name,
# .xr-var-dims,
# .xr-var-dtype,
# .xr-preview,
# .xr-attrs dt {
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
#   padding-right: 10px;
# }
#
# .xr-var-name:hover,
# .xr-var-dims:hover,
# .xr-var-dtype:hover,
# .xr-attrs dt:hover {
#   overflow: visible;
#   width: auto;
#   z-index: 1;
# }
#
# .xr-var-attrs,
# .xr-var-data {
#   display: none;
#   background-color: var(--xr-background-color) !important;
#   padding-bottom: 5px !important;
# }
#
# .xr-var-attrs-in:checked ~ .xr-var-attrs,
# .xr-var-data-in:checked ~ .xr-var-data {
#   display: block;
# }
#
# .xr-var-data > table {
#   float: right;
# }
#
# .xr-var-name span,
# .xr-var-data,
# .xr-attrs {
#   padding-left: 25px !important;
# }
#
# .xr-attrs,
# .xr-var-attrs,
# .xr-var-data {
#   grid-column: 1 / -1;
# }
#
# dl.xr-attrs {
#   padding: 0;
#   margin: 0;
#   display: grid;
#   grid-template-columns: 125px auto;
# }
#
# .xr-attrs dt,
# .xr-attrs dd {
#   padding: 0;
#   margin: 0;
#   float: left;
#   padding-right: 10px;
#   width: auto;
# }
#
# .xr-attrs dt {
#   font-weight: normal;
#   grid-column: 1;
# }
#
# .xr-attrs dt:hover span {
#   display: inline-block;
#   background: var(--xr-background-color);
#   padding-right: 10px;
# }
#
# .xr-attrs dd {
#   grid-column: 2;
#   white-space: pre-wrap;
#   word-break: break-all;
# }
#
# .xr-icon-database,
# .xr-icon-file-text2 {
#   display: inline-block;
#   vertical-align: middle;
#   width: 1em;
#   height: 1.5em !important;
#   stroke-width: 0;
#   stroke: currentColor;
#   fill: currentColor;
# }
# </style><pre class='xr-text-repr-fallback'>&lt;xarray.Dataset&gt;
# Dimensions:  (z: 1, y: 10, x: 20)
# Coordinates:
#   * z        (z) float64 -1.0
#   * y        (y) float64 0.0 0.05556 0.1111 0.1667 ... 0.3333 0.3889 0.4444 0.5
#   * x        (x) float64 0.0 0.05263 0.1053 0.1579 ... 0.8421 0.8947 0.9474 1.0
# Data variables:
#     u        (z, y, x) float64 0.9097 0.4911 0.2975 ... 0.0552 0.9303 0.2944
#     v        (z, y, x) float64 0.5405 0.7844 0.6976 ... 0.3895 0.8131 0.6203
#     w        (z, y, x) float64 0.9064 0.3229 0.4494 ... 0.3707 0.9012 0.3344
# Attributes:
#     units:      mm/s
#     long_name:  vector data</pre><div class='xr-wrap' style='display:none'><div class='xr-header'><div class='xr-obj-type'>xarray.Dataset</div></div><ul class='xr-sections'><li class='xr-sectio
# <xarray.Dataset>
# Dimensions:  (z: 1, y: 10, x: 20)
# Coordinates:
#   * z        (z) float64 -1.0
#   * y        (y) float64 0.0 0.05556 0.1111 0.1667 ... 0.3333 0.3889 0.4444 0.5
#   * x        (x) float64 0.0 0.05263 0.1053 0.1579 ... 0.8421 0.8947 0.9474 1.0
# Data variables:
#     u        (z, y, x) float64 0.9097 0.4911 0.2975 ... 0.0552 0.9303 0.2944
#     v        (z, y, x) float64 0.5405 0.7844 0.6976 ... 0.3895 0.8131 0.6203
#     w        (z, y, x) float64 0.9064 0.3229 0.4494 ... 0.3707 0.9012 0.3344
# Attributes:
#     units:      mm/s
#     long_name:  vector data

# %% [markdown]
# A `xr.Dataset` is received, which we can work on, e.g. compute the magnitude and plot it:

# %%
vel.compute_magnitude()
vel.magnitude.plot()

# %% [markdown]
# As seen, the vector components can be addressed passing the keyword `names` in the call-statement. We could also use the keyword `standard_name`.
# To make use of the `standard_name` attribute, `VelocityDataset` is the specialized version of the `Vector` property. If sarches for the keywords `x_velocity`, `y_velocity` and `z_velocity`. This approach obviously only works if those attribtues are unique within the HDF group. If not, `name` can still be passed in the call-statement:

# %%
with h5tbx.H5Flow(filename) as h5:
    vel_uvw = h5.VelocityVector[0:1, :, :]
    vel_uv = h5.VelocityVector(names=('u', 'v'))[0:1, :, :]

# %% [markdown]
# ## Connecting datast to a devices
# Assume we have experiment data, e.g. we measured the pressure. We can reference the measurement device in the dataset like so:

# %%
with h5tbx.H5Flow() as h5:
    h5.create_group('devices')
    device_grp = h5.create_group('devices/PressureSensor')
    device_grp.attrs['manufacturer'] = 'unknown'
    device_grp.create_dataset('x', data=0, units='m', standard_name='x_coordinate')
    device_grp.create_dataset('y', data=0, units='m', standard_name='y_coordinate')
    device_grp.create_dataset('z', data=0, units='m', standard_name='z_coordinate')
    ds = h5.create_dataset('pressure', data=np.random.random(100), units='Pa', standard_name='pressure',
                          device=device_grp)
    print(ds.device)
    print(type(ds.device))
# Out:
# Device "PressureSensor" from "unknown" @(0, 0, 0) [m])
# <class 'h5rdmtoolbox.wrapper.h5flow.Device'>

# %% [markdown]
# **Alternative 1:** We can first use the `Device` class to create an object, which we write to the hdf group and then create the reference:

# %%
p_sensor = h5tbx.wrapper.h5flow.Device('PressureSensor', manufacturer='unknown',
                  x=(0, dict(units='m',standard_name='x_coordinate')),
                  y=(0, dict(units='m',standard_name='y_coordinate')),
                  z=(0, dict(units='m',standard_name='z_coordinate')))
p_sensor
# Out:
# Device "PressureSensor" from "unknown" @(0, 0, 0) [m])

# %%
with h5tbx.H5Flow() as h5:
    devices_grp = h5.create_group('devices')
    sensor_grp = p_sensor.to_hdf_group(devices_grp)
    
    ds = h5.create_dataset('pressure', data=np.random.random(100), units='Pa', standard_name='pressure',
                          device=sensor_grp)
    ds.device = sensor_grp
    print(ds.device)
    print(type(ds.device))
# Out:
# Device "PressureSensor" from "unknown" @(0, 0, 0) [m])
# <class 'h5rdmtoolbox.wrapper.h5flow.Device'>

# %%
with h5tbx.H5Flow() as h5:    
    ds = h5.create_dataset('pressure', data=np.random.random(100), units='Pa', standard_name='pressure')
    ds.device = p_sensor

# %% [markdown]
# ---
# ## H5PIV
#
# Velocity is a vector quantity. In the HDF file each component generally is stored as an individual data variable. To get the full vector in one variable the attribute `VelocityVector` can be called. Slicing this object will assigned it with the respectve arrays from the HDF datasets. In this case x- and y-velociy datasets are siced and merged into a `xr.Dataset`. The `VelocityVector` class is wrapped around the `xr.Dataset` class and has additional methods, like `compute_magnitude()`.
#
# Note, that `VelocityVector` is not a property of `H5PIV` by default but is added afterwards, similar to how dataarray-ccessors are added to an `xr.DataArray`.

# %%
with h5tbx.tutorial.get_H5PIV('minimal_flow', mode='r') as h5:
    vel = h5.VelocityVector[:]
vel.compute_magnitude()
vel.magnitude[0,0,:,:].plot()

# %% [markdown]
# ### Post-processing with `H5PIV`
#
# Based on standard names velocity, velocity gradients and other variables are identified. Each group therefore should have only one velocity vector, otherwise it is not clear from which to compute e.g. the turbulent kinetic energy.<br>
# From each group, multiple fluid-specific post-processing methods can be called. They store the result in the respective group if required data was correcly identified:

# %%
with h5tbx.tutorial.get_H5PIV('minimal_flow', mode='r+') as h5:
    rm = h5.compute_running_mean('u')
    rs = h5.compute_running_std('u')
    (rs[0,-1,:,:]/rm[0,-1,:,:]).plot(vmin=-2, vmax=2)
    h5.dump()
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
#
# .h5tb-unit {
#     width: 96px;
#     white-space: nowrap;
#     padding-right: 2px;
#     text-align: right;
#     color: #555;
#     font-style: italic;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: #fff;
#     padding-bottom: 6px;
#     color: #555;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: #fff;
# }
#
# .h5tb-dim-highlight {
#     background-color: rgba(3, 169, 244, .2);
#     cursor: pointer;
# }</style></head>
# <p>tmp5.hdf</p>
# <p>Check resuted in 2 issues.</p>
#
# <div class='h5tb-warp'>
#
#           <ul style="list-style-type: none;" class="h5grp-sections">
#                 <li>
#                     <input id="group-ds-/-4620642900" type="checkbox" checked>
#                     <label style="font-weight: bold" for="group-ds-/-4620642900">
#                     /<span>(15)</span></label>
#
#
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">CREATION_TIME : 2022-07-10T13:18:45Z+0200</li><li style="list-style-type: none; font-style: italic">__edited_with_wrapper_class__ : H5PIV</li><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.1.0</li><li style="list-style-type: none; font-style: italic">__h5wrapperpy_version__ : 0.5.4</li><li style="list-style-type: none; font-style: italic">__standard_name_table__ : piv-v1</li><li style="list-style-type: none; font-style: italic">__wrcls__ : H5PIV</li><li style="list-style-type: none; font-style: italic">__x2hdf_version__ : 1.0.0</li><li style="list-style-type: none; font-style: italic">creation_time : 2022-04-26_08:06:06</li><li style="list-style-type: none; font-style: italic">h5wrapperpy_version : 0.4.0</li><li style="list-style-type: none; font-style: italic">modification_time : 2022-07-22T13:06:21Z+0200</li><li style="list-style-type: none; font-style: italic">piv_dimension : 2D3C</li><li style="list-style-type: none; font-style: italic">piv_type : PIVCase</li><li style="list-style-type: none; font-style: italic">software : PIVTec PIVview</li><li style="list-style-type: none; font-style: italic">title : Minimal fluid example</li>
#                 </ul>
#
#                 <ul id="ds-1-/time-4623637600" class="h5tb-var-list">
#                 <input id="ds-2-/time-4623640200" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/time-4623640200">time</label>
#                 <span class="h5tb-dims">(5,)</span>  [
#                 <span class="h5tb-unit">s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : Recording time since start.</li><li style="list-style-type: none; font-style:
#          italic">standard_name : time</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/tke-4624341200" class="h5tb-var-list">
#                 <input id="ds-2-/tke-4624343500" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/tke-4624343500">tke</label>
#                 <span class="h5tb-dims">(z: 2, y: 110, x: 127)</span>  [
#                 <span class="h5tb-unit">m**2/s**2</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style:
#          italic">standard_name : turbulent_kinetic_energy</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/u-4625017600" class="h5tb-var-list">
#                 <input id="ds-2-/u-4625019800" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/u-4625019800">u</label>
#                 <span class="h5tb-dims">(z: 2, time: 5, y: 110, x: 127)</span>  [
#                 <span class="h5tb-unit">m/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style:
#          italic">standard_name : x_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/uu-4625544100" class="h5tb-var-list">
#                 <input id="ds-2-/uu-4625546300" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/uu-4625546300">uu</label>
#                 <span class="h5tb-dims">(z: 2, y: 110, x: 127)</span>  [
#                 <span class="h5tb-unit">m**2/s**2</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style:
#          italic">standard_name : xx_reynolds_stress</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/uv-4626094800" class="h5tb-var-list">
#                 <input id="ds-2-/uv-4626097000" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/uv-4626097000">uv</label>
#                 <span class="h5tb-dims">(z: 2, y: 110, x: 127)</span>  [
#                 <span class="h5tb-unit">m**2/s**2</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style:
#          italic">standard_name : xy_reynolds_stress</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/uw-4626637100" class="h5tb-var-list">
#                 <input id="ds-2-/uw-4626639200" class="h5tb-varname-in" type="chec

# %% [markdown]
# ### Valid vector detection probability (vdp)

# %%
with h5tbx.tutorial.get_H5PIV('vortex_snapshot', 'r+') as h5:
    h5['piv_flags'].attrs.rename('flag_translation', 'flag_meanings')
    h5.get_dataset_by_standard_name('piv_flag').compute_vdp()
    h5.dump()
    print(h5.post.vdp[()])
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
#
# .h5tb-unit {
#     width: 96px;
#     white-space: nowrap;
#     padding-right: 2px;
#     text-align: right;
#     color: #555;
#     font-style: italic;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: #fff;
#     padding-bottom: 6px;
#     color: #555;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: #fff;
# }
#
# .h5tb-dim-highlight {
#     background-color: rgba(3, 169, 244, .2);
#     cursor: pointer;
# }</style></head>
# <p>tmp6.hdf</p>
# <p>Check resuted in 2 issues.</p>
#
# <div class='h5tb-warp'>
#
#           <ul style="list-style-type: none;" class="h5grp-sections">
#                 <li>
#                     <input id="group-ds-/-4890783400" type="checkbox" checked>
#                     <label style="font-weight: bold" for="group-ds-/-4890783400">
#                     /<span>(30)</span></label>
#
#
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">CREATION_TIME : 2022-07-10T11:08:44Z+0200</li><li style="list-style-type: none; font-style: italic">__edited_with_wrapper_class__ : H5File</li><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.1.0</li><li style="list-style-type: none; font-style: italic">__h5wrapperpy_version__ : 0.5.4</li><li style="list-style-type: none; font-style: italic">__standard_name_table__ : piv-v1</li><li style="list-style-type: none; font-style: italic">__wrcls__ : H5PIV</li><li style="list-style-type: none; font-style: italic">__x2hdf_version__ : 0.5.4</li><li style="list-style-type: none; font-style: italic">configuration : {'interpolation': False, 'apply_mask': T...</li><li style="list-style-type: none; font-style: italic">creation_time : 2022-06-20_21:44:46</li><li style="list-style-type: none; font-style: italic">h5wrapperpy_version : 0.5.4</li><li style="list-style-type: none; font-style: italic">modification_time : 2022-07-25T14:03:48Z+0200</li><li style="list-style-type: none; font-style: italic">piv_dimension : 2D2C</li><li style="list-style-type: none; font-style: italic">piv_parameters : {'---- PIV image pre-processing paramete...</li><li style="list-style-type: none; font-style: italic">piv_type : PIVSnapshot</li><li style="list-style-type: none; font-style: italic">plane_directory : C:\Users\da4323\Documents\programming\gi...</li><li style="list-style-type: none; font-style: italic">software : PIVTec PIVview</li><li style="list-style-type: none; font-style: italic">title : PIV snapshot file generated from a singl...</li>
#                 </ul>
#
#                 <ul id="ds-1-/dudx-4896610300" class="h5tb-var-list">
#                 <input id="ds-2-/dudx-4896612900" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/dudx-4896612900">dudx</label>
#                 <span class="h5tb-dims">(y: 29, x: 31)</span>  [
#                 <span class="h5tb-unit">1/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : velocity gradient du/dx</li><li style="list-style-type: none; font-style:
#          italic">standard_name : x_derivative_of_x_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/dudy-4897152900" class="h5tb-var-list">
#                 <input id="ds-2-/dudy-4897155100" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/dudy-4897155100">dudy</label>
#                 <span class="h5tb-dims">(y: 29, x: 31)</span>  [
#                 <span class="h5tb-unit">1/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : velocity gradient du/dy</li><li style="list-style-type: none; font-style:
#          italic">standard_name : y_derivative_of_x_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/dvdx-4897731000" class="h5tb-var-list">
#                 <input id="ds-2-/dvdx-4897733100" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/dvdx-4897733100">dvdx</label>
#                 <span class="h5tb-dims">(y: 29, x: 31)</span>  [
#                 <span class="h5tb-unit">1/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : velocity gradient dv/dx</li><li style="list-style-type: none; font-style:
#          italic">standard_name : x_derivative_of_y_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/dvdy-4898257000" class="h5tb-var-list">
#                 <input id="ds-2-/dvdy-4898259700" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/dvdy-4898259700">dvdy</label>
#                 <span class="h5tb-dims">(y: 29, x: 31)</span>  [
#                 <span class="h5tb-unit">1/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : velocity gradient dv/dy</li><li style="list-style-type: none; font-style:
#          italic">standard_name : y_derivative_of_y_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-
# <xarray.DataArray 'vdp' (dim_0: 1)>
# array([1.], dtype=float32)
# Dimensions without coordinates: dim_0
# Attributes:
#     description:  The absolute or relative number of valid vectors of the res...
#     long_name:    valid detection probability
#     units:

# %% [markdown]
# ## Computing PIV uncertainty

# %% [markdown]
# Get an example HDF filename from the ILA vortex pair example (https://www.pivtec.com/pivview.html):
#
# To compute the uncertainty of a PIV measurement, we need to gather some specific datasets, namely the at minimum the pixel coordinates, the displacements and the raw images. The class property `UncertaintyDataset` does this for us. Calling it will return a `xarray.Dataset` with the displacement variables.
#
# Let's load the vortex example and fetch image A and imabe B:

# %%
with h5tbx.tutorial.get_H5PIV('vortex_snapshot', 'r+') as h5:
    disp = h5.DisplacementVector[:,:]
    imgA = h5.imgA[:,:]
    imgB = h5.imgB[:,:]
disp
# Out:
# <div><svg style="position: absolute; width: 0; height: 0; overflow: hidden">
# <defs>
# <symbol id="icon-database" viewBox="0 0 32 32">
# <path d="M16 0c-8.837 0-16 2.239-16 5v4c0 2.761 7.163 5 16 5s16-2.239 16-5v-4c0-2.761-7.163-5-16-5z"></path>
# <path d="M16 17c-8.837 0-16-2.239-16-5v6c0 2.761 7.163 5 16 5s16-2.239 16-5v-6c0 2.761-7.163 5-16 5z"></path>
# <path d="M16 26c-8.837 0-16-2.239-16-5v6c0 2.761 7.163 5 16 5s16-2.239 16-5v-6c0 2.761-7.163 5-16 5z"></path>
# </symbol>
# <symbol id="icon-file-text2" viewBox="0 0 32 32">
# <path d="M28.681 7.159c-0.694-0.947-1.662-2.053-2.724-3.116s-2.169-2.030-3.116-2.724c-1.612-1.182-2.393-1.319-2.841-1.319h-15.5c-1.378 0-2.5 1.121-2.5 2.5v27c0 1.378 1.122 2.5 2.5 2.5h23c1.378 0 2.5-1.122 2.5-2.5v-19.5c0-0.448-0.137-1.23-1.319-2.841zM24.543 5.457c0.959 0.959 1.712 1.825 2.268 2.543h-4.811v-4.811c0.718 0.556 1.584 1.309 2.543 2.268zM28 29.5c0 0.271-0.229 0.5-0.5 0.5h-23c-0.271 0-0.5-0.229-0.5-0.5v-27c0-0.271 0.229-0.5 0.5-0.5 0 0 15.499-0 15.5 0v7c0 0.552 0.448 1 1 1h7v19.5z"></path>
# <path d="M23 26h-14c-0.552 0-1-0.448-1-1s0.448-1 1-1h14c0.552 0 1 0.448 1 1s-0.448 1-1 1z"></path>
# <path d="M23 22h-14c-0.552 0-1-0.448-1-1s0.448-1 1-1h14c0.552 0 1 0.448 1 1s-0.448 1-1 1z"></path>
# <path d="M23 18h-14c-0.552 0-1-0.448-1-1s0.448-1 1-1h14c0.552 0 1 0.448 1 1s-0.448 1-1 1z"></path>
# </symbol>
# </defs>
# </svg>
# <style>/* CSS stylesheet for displaying xarray objects in jupyterlab.
#  *
#  */
#
# :root {
#   --xr-font-color0: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --xr-font-color2: var(--jp-content-font-color2, rgba(0, 0, 0, 0.54));
#   --xr-font-color3: var(--jp-content-font-color3, rgba(0, 0, 0, 0.38));
#   --xr-border-color: var(--jp-border-color2, #e0e0e0);
#   --xr-disabled-color: var(--jp-layout-color3, #bdbdbd);
#   --xr-background-color: var(--jp-layout-color0, white);
#   --xr-background-color-row-even: var(--jp-layout-color1, white);
#   --xr-background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme=dark],
# body[data-theme=dark],
# body.vscode-dark {
#   --xr-font-color0: rgba(255, 255, 255, 1);
#   --xr-font-color2: rgba(255, 255, 255, 0.54);
#   --xr-font-color3: rgba(255, 255, 255, 0.38);
#   --xr-border-color: #1F1F1F;
#   --xr-disabled-color: #515151;
#   --xr-background-color: #111111;
#   --xr-background-color-row-even: #111111;
#   --xr-background-color-row-odd: #313131;
# }
#
# .xr-wrap {
#   display: block !important;
#   min-width: 300px;
#   max-width: 700px;
# }
#
# .xr-text-repr-fallback {
#   /* fallback to plain text repr when CSS is not injected (untrusted notebook) */
#   display: none;
# }
#
# .xr-header {
#   padding-top: 6px;
#   padding-bottom: 6px;
#   margin-bottom: 4px;
#   border-bottom: solid 1px var(--xr-border-color);
# }
#
# .xr-header > div,
# .xr-header > ul {
#   display: inline;
#   margin-top: 0;
#   margin-bottom: 0;
# }
#
# .xr-obj-type,
# .xr-array-name {
#   margin-left: 2px;
#   margin-right: 10px;
# }
#
# .xr-obj-type {
#   color: var(--xr-font-color2);
# }
#
# .xr-sections {
#   padding-left: 0 !important;
#   display: grid;
#   grid-template-columns: 150px auto auto 1fr 20px 20px;
# }
#
# .xr-section-item {
#   display: contents;
# }
#
# .xr-section-item input {
#   display: none;
# }
#
# .xr-section-item input + label {
#   color: var(--xr-disabled-color);
# }
#
# .xr-section-item input:enabled + label {
#   cursor: pointer;
#   color: var(--xr-font-color2);
# }
#
# .xr-section-item input:enabled + label:hover {
#   color: var(--xr-font-color0);
# }
#
# .xr-section-summary {
#   grid-column: 1;
#   color: var(--xr-font-color2);
#   font-weight: 500;
# }
#
# .xr-section-summary > span {
#   display: inline-block;
#   padding-left: 0.5em;
# }
#
# .xr-section-summary-in:disabled + label {
#   color: var(--xr-font-color2);
# }
#
# .xr-section-summary-in + label:before {
#   display: inline-block;
#   content: '►';
#   font-size: 11px;
#   width: 15px;
#   text-align: center;
# }
#
# .xr-section-summary-in:disabled + label:before {
#   color: var(--xr-disabled-color);
# }
#
# .xr-section-summary-in:checked + label:before {
#   content: '▼';
# }
#
# .xr-section-summary-in:checked + label > span {
#   display: none;
# }
#
# .xr-section-summary,
# .xr-section-inline-details {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# .xr-section-inline-details {
#   grid-column: 2 / -1;
# }
#
# .xr-section-details {
#   display: none;
#   grid-column: 1 / -1;
#   margin-bottom: 5px;
# }
#
# .xr-section-summary-in:checked ~ .xr-section-details {
#   display: contents;
# }
#
# .xr-array-wrap {
#   grid-column: 1 / -1;
#   display: grid;
#   grid-template-columns: 20px auto;
# }
#
# .xr-array-wrap > label {
#   grid-column: 1;
#   vertical-align: top;
# }
#
# .xr-preview {
#   color: var(--xr-font-color3);
# }
#
# .xr-array-preview,
# .xr-array-data {
#   padding: 0 5px !important;
#   grid-column: 2;
# }
#
# .xr-array-data,
# .xr-array-in:checked ~ .xr-array-preview {
#   display: none;
# }
#
# .xr-array-in:checked ~ .xr-array-data,
# .xr-array-preview {
#   display: inline-block;
# }
#
# .xr-dim-list {
#   display: inline-block !important;
#   list-style: none;
#   padding: 0 !important;
#   margin: 0;
# }
#
# .xr-dim-list li {
#   display: inline-block;
#   padding: 0;
#   margin: 0;
# }
#
# .xr-dim-list:before {
#   content: '(';
# }
#
# .xr-dim-list:after {
#   content: ')';
# }
#
# .xr-dim-list li:not(:last-child):after {
#   content: ',';
#   padding-right: 5px;
# }
#
# .xr-has-index {
#   font-weight: bold;
# }
#
# .xr-var-list,
# .xr-var-item {
#   display: contents;
# }
#
# .xr-var-item > div,
# .xr-var-item label,
# .xr-var-item > .xr-var-name span {
#   background-color: var(--xr-background-color-row-even);
#   margin-bottom: 0;
# }
#
# .xr-var-item > .xr-var-name:hover span {
#   padding-right: 5px;
# }
#
# .xr-var-list > li:nth-child(odd) > div,
# .xr-var-list > li:nth-child(odd) > label,
# .xr-var-list > li:nth-child(odd) > .xr-var-name span {
#   background-color: var(--xr-background-color-row-odd);
# }
#
# .xr-var-name {
#   grid-column: 1;
# }
#
# .xr-var-dims {
#   grid-column: 2;
# }
#
# .xr-var-dtype {
#   grid-column: 3;
#   text-align: right;
#   color: var(--xr-font-color2);
# }
#
# .xr-var-preview {
#   grid-column: 4;
# }
#
# .xr-var-name,
# .xr-var-dims,
# .xr-var-dtype,
# .xr-preview,
# .xr-attrs dt {
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
#   padding-right: 10px;
# }
#
# .xr-var-name:hover,
# .xr-var-dims:hover,
# .xr-var-dtype:hover,
# .xr-attrs dt:hover {
#   overflow: visible;
#   width: auto;
#   z-index: 1;
# }
#
# .xr-var-attrs,
# .xr-var-data {
#   display: none;
#   background-color: var(--xr-background-color) !important;
#   padding-bottom: 5px !important;
# }
#
# .xr-var-attrs-in:checked ~ .xr-var-attrs,
# .xr-var-data-in:checked ~ .xr-var-data {
#   display: block;
# }
#
# .xr-var-data > table {
#   float: right;
# }
#
# .xr-var-name span,
# .xr-var-data,
# .xr-attrs {
#   padding-left: 25px !important;
# }
#
# .xr-attrs,
# .xr-var-attrs,
# .xr-var-data {
#   grid-column: 1 / -1;
# }
#
# dl.xr-attrs {
#   padding: 0;
#   margin: 0;
#   display: grid;
#   grid-template-columns: 125px auto;
# }
#
# .xr-attrs dt,
# .xr-attrs dd {
#   padding: 0;
#   margin: 0;
#   float: left;
#   padding-right: 10px;
#   width: auto;
# }
#
# .xr-attrs dt {
#   font-weight: normal;
#   grid-column: 1;
# }
#
# .xr-attrs dt:hover span {
#   display: inline-block;
#   background: var(--xr-background-color);
#   padding-right: 10px;
# }
#
# .xr-attrs dd {
#   grid-column: 2;
#   white-space: pre-wrap;
#   word-break: break-all;
# }
#
# .xr-icon-database,
# .xr-icon-file-text2 {
#   display: inline-block;
#   vertical-align: middle;
#   width: 1em;
#   height: 1.5em !important;
#   stroke-width: 0;
#   stroke: currentColor;
#   fill: currentColor;
# }
# </style><pre class='xr-text-repr-fallback'>&lt;xarray.Dataset&gt;
# Dimensions:  (y: 29, x: 31)
# Coordinates:
#   * y        (y) float64 -464.0 -448.0 -432.0 -416.0 ... -64.0 -48.0 -32.0 -16.0
#     iy       (y) int32 16 32 48 64 80 96 112 128 ... 368 384 400 416 432 448 464
#   * x        (x) float64 16.0 32.0 48.0 64.0 80.0 ... 448.0 464.0 480.0 496.0
#     ix       (x) int32 16 32 48 64 80 96 112 128 ... 400 416 432 448 464 480 496
#     time     int32 0
#     z        float64 0.0
# Data variables:
#     dx       (y, x) float32 nan nan nan nan nan ... 1.127 1.073 0.8495 0.7958
#     dy       (y, x) float32 nan nan nan nan nan ... 0.08971 0.117 0.07952 0.1089
# Attributes:
#     units:      pixel
#     long_name:  vector data</pre><div class='xr-wrap' style='display:none'><div class='xr-hea
# <xarray.Dataset>
# Dimensions:  (y: 29, x: 31)
# Coordinates:
#   * y        (y) float64 -464.0 -448.0 -432.0 -416.0 ... -64.0 -48.0 -32.0 -16.0
#     iy       (y) int32 16 32 48 64 80 96 112 128 ... 368 384 400 416 432 448 464
#   * x        (x) float64 16.0 32.0 48.0 64.0 80.0 ... 448.0 464.0 480.0 496.0
#     ix       (x) int32 16 32 48 64 80 96 112 128 ... 400 416 432 448 464 480 496
#     time     int32 0
#     z        float64 0.0
# Data variables:
#     dx       (y, x) float32 nan nan nan nan nan ... 1.127 1.073 0.8495 0.7958
#     dy       (y, x) float32 nan nan nan nan nan ... 0.08971 0.117 0.07952 0.1089
# Attributes:
#     units:      pixel
#     long_name:  vector data

# %% [markdown]
# The uncertainty dataset has the coordinates `x` and `y`, the displacements arrays `dx` and `dy` but also the pixel coordinates `ix` and `iy`
#
# Next, let's create a more or less random uncertainty method. In this example we do not compute the real error but assume one, just to explain the workflow of cumputing the uncertainty from the dataset:

# %%
def my_uncertainty_method(uds, imgA, imgB):
    """
    Dummy uncertainty method for this tutorial.
    Returns the same dataset but with added uncertainties
    
    Parameters
    ----------
    uds: XRUncertaintyDataset
        The uncertainty dataset containing, x, y, ix, iy, dx, dy, ...
    imgA: np.ndarray
        2d PIV image A. Will not be touch in this example
    imgB: np.ndarray
        2d PIV image B. Will not be touch in this example
        
    Returns
    -------
    uds: XRUncertaintyDataset    
    """
    import xarray as xr
    xerr = 0.05
    yerr = 0.075
    udx = np.abs(uds.dx)*xerr
    uds['udx'] = xr.DataArray(dims=uds.dx.dims, data=udx,
                                        attrs={'standard_name': f'uncertainty_of_{uds.dx.standard_name}',
                                               'units': 'pixel',
                                               'piv_uncertainty_method': 'my_uncertainty_method'})
    udy = np.abs(uds.dy)*yerr
    uds['udy'] = xr.DataArray(dims=uds.dy.dims, data=udy,
                                        attrs={'standard_name': f'uncertainty_of_{uds.dy.standard_name}',
                                               'units': 'pixel',
                                               'piv_uncertainty_method': 'my_uncertainty_method'})
    return uds

# %%
un = disp.compute_uncertainty(my_uncertainty_method, imgA, imgB)

# %%
un.compute_magnitude()
_ = un.magnitude[:].plot.contourf(vmax=6, vmin=0)

# %%
udx = un.get_by_standard_name('uncertainty_of_x_displacement')
_ = udx.where(np.abs(udx) < 20).plot.contourf()
print(f'Error in x-direction: {udx.mean().values}')
print(f'Absolute relative error in x-direction: {np.divide(udx, np.abs(un.dx)).mean().values}')
# Out:
# Error in x-direction: 0.03808027505874634
# Absolute relative error in x-direction: 0.05000000447034836

# %%
h5tbx.conventions.identifier.STRICT = False
# uncertainty_of_x_displacement is not part of the standard name table at this moment. 
# Don't check if standard names are in the respective table. this can be done by diabeling the "strictness" of checking standard names

# %%
with h5tbx.H5PIV(h5.hdf_filename, 'r+') as h5:
    h5.create_group('uncertainty', overwrite=True)
    h5['uncertainty'].create_dataset('delta_dx', data=un.get_by_standard_name('uncertainty_of_x_displacement'), overwrite=True)
    h5['uncertainty'].create_dataset('delta_dy', data=un.get_by_standard_name('uncertainty_of_x_displacement'), overwrite=True)

# %%
with h5tbx.H5PIV(h5.hdf_filename, 'r+') as h5:
    h5.dump()
    h5.uncertainty.delta_dx[:,:].plot()
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
#
# .h5tb-unit {
#     width: 96px;
#     white-space: nowrap;
#     padding-right: 2px;
#     text-align: right;
#     color: #555;
#     font-style: italic;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: #fff;
#     padding-bottom: 6px;
#     color: #555;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: #fff;
# }
#
# .h5tb-dim-highlight {
#     background-color: rgba(3, 169, 244, .2);
#     cursor: pointer;
# }</style></head>
# <p>tmp7.hdf</p>
# <p>Check resuted in 2 issues.</p>
#
# <div class='h5tb-warp'>
#
#           <ul style="list-style-type: none;" class="h5grp-sections">
#                 <li>
#                     <input id="group-ds-/-5508907200" type="checkbox" checked>
#                     <label style="font-weight: bold" for="group-ds-/-5508907200">
#                     /<span>(30)</span></label>
#
#
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">CREATION_TIME : 2022-07-10T11:08:44Z+0200</li><li style="list-style-type: none; font-style: italic">__edited_with_wrapper_class__ : H5File</li><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.1.0</li><li style="list-style-type: none; font-style: italic">__h5wrapperpy_version__ : 0.5.4</li><li style="list-style-type: none; font-style: italic">__standard_name_table__ : piv-v1</li><li style="list-style-type: none; font-style: italic">__wrcls__ : H5PIV</li><li style="list-style-type: none; font-style: italic">__x2hdf_version__ : 0.5.4</li><li style="list-style-type: none; font-style: italic">configuration : {'interpolation': False, 'apply_mask': T...</li><li style="list-style-type: none; font-style: italic">creation_time : 2022-06-20_21:44:46</li><li style="list-style-type: none; font-style: italic">h5wrapperpy_version : 0.5.4</li><li style="list-style-type: none; font-style: italic">modification_time : 2022-07-25T14:03:48Z+0200</li><li style="list-style-type: none; font-style: italic">piv_dimension : 2D2C</li><li style="list-style-type: none; font-style: italic">piv_parameters : {'---- PIV image pre-processing paramete...</li><li style="list-style-type: none; font-style: italic">piv_type : PIVSnapshot</li><li style="list-style-type: none; font-style: italic">plane_directory : C:\Users\da4323\Documents\programming\gi...</li><li style="list-style-type: none; font-style: italic">software : PIVTec PIVview</li><li style="list-style-type: none; font-style: italic">title : PIV snapshot file generated from a singl...</li>
#                 </ul>
#
#                 <ul id="ds-1-/dudx-5514425600" class="h5tb-var-list">
#                 <input id="ds-2-/dudx-5514428300" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/dudx-5514428300">dudx</label>
#                 <span class="h5tb-dims">(y: 29, x: 31)</span>  [
#                 <span class="h5tb-unit">1/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : velocity gradient du/dx</li><li style="list-style-type: none; font-style:
#          italic">standard_name : x_derivative_of_x_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/dudy-5515030100" class="h5tb-var-list">
#                 <input id="ds-2-/dudy-5515032400" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/dudy-5515032400">dudy</label>
#                 <span class="h5tb-dims">(y: 29, x: 31)</span>  [
#                 <span class="h5tb-unit">1/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : velocity gradient du/dy</li><li style="list-style-type: none; font-style:
#          italic">standard_name : y_derivative_of_x_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/dvdx-5515548900" class="h5tb-var-list">
#                 <input id="ds-2-/dvdx-5515550800" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/dvdx-5515550800">dvdx</label>
#                 <span class="h5tb-dims">(y: 29, x: 31)</span>  [
#                 <span class="h5tb-unit">1/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : velocity gradient dv/dx</li><li style="list-style-type: none; font-style:
#          italic">standard_name : x_derivative_of_y_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-1-/dvdy-5516053700" class="h5tb-var-list">
#                 <input id="ds-2-/dvdy-5516055700" class="h5tb-varname-in" type="checkbox">
#                 <label class='h5tb-varname'
#                     for="ds-2-/dvdy-5516055700">dvdy</label>
#                 <span class="h5tb-dims">(y: 29, x: 31)</span>  [
#                 <span class="h5tb-unit">1/s</span>]
# <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : velocity gradient dv/dy</li><li style="list-style-type: none; font-style:
#          italic">standard_name : y_derivative_of_y_velocity</li>
#
#                 </ul>
#
#              </ul>
#
#
#                 <ul id="ds-
