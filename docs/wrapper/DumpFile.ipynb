# %% [markdown]
# # Inspecting the File content
#
# To get an overview of the file content, a tree-view representation is provided. It can be called using `.dump()`. This, however, is only possible in notebooks. Outside of it (e.g. in a normal python console) call `.sdump()` (string-dump) to get a "raw", non-interactive, tree view:

# %%
import h5rdmtoolbox as h5tbx
from h5rdmtoolbox import tutorial

# get some example files:
list_of_hdf_filenames = tutorial.Database.generate_test_files()

# dump the content of the first file in the list:
with h5tbx.File(list_of_hdf_filenames[0]) as h5:
    h5.dump()
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
#
# .h5tb-unit {
#     width: 96px;
#     white-space: nowrap;
#     padding-right: 2px;
#     text-align: right;
#     color: #555;
#     font-style: italic;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: #fff;
#     padding-bottom: 6px;
#     color: #555;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: #fff;
# }
#
# .h5tb-dim-highlight {
#     background-color: rgba(3, 169, 244, .2);
#     cursor: pointer;
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--4927559100" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--4927559100">
#                         /<span>(4)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__db_file_type__ : piv_case</li><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.8rc2</li><li style="list-style-type: none; font-style: italic">operator : John</li>
#                     </ul>
#
#                 <ul id="ds-1-/u-4929087300" class="h5tb-var-list">
#                     <input id="ds-2-/u-4929089700" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/u-4929089700">u</label>
#                     <span class="h5tb-dims">(2, 5, 64, x: 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : u-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/v-4929681400" class="h5tb-var-list">
#                     <input id="ds-2-/v-4929683600" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/v-4929683600">v</label>
#                     <span class="h5tb-dims">(2, 5, 64, x: 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : v-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/x-4930002300" class="h5tb-var-list">
#                     <input id="ds-2-/x-4930004500" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/x-4930004500">x</label>
#                     <span class="h5tb-dims">(86) [int32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : x-coordinate</li><li style="list-style-type: none; font-style: italic">units : m</li>
#                 </ul>
#                 </ul>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds-timeAverages-4930395600" type="checkbox" >
#                         <label style="font-weight: bold" for="group-ds-timeAverages-4930395600">
#                         timeAverages<span>(2)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : time averaged data</li>
#                     </ul>
#
#                 <ul id="ds-1-/timeAverages/u-4931117300" class="h5tb-var-list">
#                     <input id="ds-2-/timeAverages/u-4931119600" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/timeAverages/u-4931119600">u</label>
#                     <span class="h5tb-dims">(2, 64, 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : mean u-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/timeAverages/v-4931439300" class="h5tb-var-list">
#                     <input id="ds-2-/timeAverages/v-4931441800" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/timeAverages/v-4931441800">v</label>
#                     <span class="h5tb-dims">(2, 64, 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : mean v-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>

# %% [markdown]
# ## User-defined representation
#
# Every convention that is selected may have a different way of displaying the content. For the built-in convention "h5tbx", the attribute "units" is put in square brackets behind the dataset name and thus is not listed as an attribute:

# %%
h5tbx.use('h5tbx')

with h5tbx.File(list_of_hdf_filenames[0]) as h5:
    h5.dump()
# Out:
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
#
# .h5tb-unit {
#     width: 96px;
#     white-space: nowrap;
#     padding-right: 2px;
#     text-align: right;
#     color: #555;
#     font-style: italic;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: #fff;
#     padding-bottom: 6px;
#     color: #555;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: #fff;
# }
#
# .h5tb-dim-highlight {
#     background-color: rgba(3, 169, 244, .2);
#     cursor: pointer;
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--4944076100" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--4944076100">
#                         /<span>(4)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__db_file_type__ : piv_case</li><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.8rc2</li><li style="list-style-type: none; font-style: italic">operator : John</li>
#                     </ul>
#
#                 <ul id="ds-1-/u-4947609900" class="h5tb-var-list">
#                     <input id="ds-2-/u-4947614700" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/u-4947614700">u</label>
#                     <span class="h5tb-dims">(2, 5, 64, x: 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : u-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/v-4948510300" class="h5tb-var-list">
#                     <input id="ds-2-/v-4948513100" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/v-4948513100">v</label>
#                     <span class="h5tb-dims">(2, 5, 64, x: 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : v-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/x-4949033600" class="h5tb-var-list">
#                     <input id="ds-2-/x-4949036200" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/x-4949036200">x</label>
#                     <span class="h5tb-dims">(86) [int32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : x-coordinate</li><li style="list-style-type: none; font-style: italic">units : m</li>
#                 </ul>
#                 </ul>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds-timeAverages-4949485100" type="checkbox" >
#                         <label style="font-weight: bold" for="group-ds-timeAverages-4949485100">
#                         timeAverages<span>(2)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : time averaged data</li>
#                     </ul>
#
#                 <ul id="ds-1-/timeAverages/u-4950304000" class="h5tb-var-list">
#                     <input id="ds-2-/timeAverages/u-4950306600" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/timeAverages/u-4950306600">u</label>
#                     <span class="h5tb-dims">(2, 64, 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : mean u-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/timeAverages/v-4950726900" class="h5tb-var-list">
#                     <input id="ds-2-/timeAverages/v-4950729300" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/timeAverages/v-4950729300">v</label>
#                     <span class="h5tb-dims">(2, 64, 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : mean v-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>

# %% [markdown]
# ## Multi-file inspection
#
# To inspect multiple files simultaneous, use `H5Files` instead of `File`:

# %%
with h5tbx.FileDB(list_of_hdf_filenames[0:2]) as h5files:
    print(h5files)
    h5files[0].dump()
    h5files[1].dump()
# Out:
# <Files (2 files)>
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
#
# .h5tb-unit {
#     width: 96px;
#     white-space: nowrap;
#     padding-right: 2px;
#     text-align: right;
#     color: #555;
#     font-style: italic;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: #fff;
#     padding-bottom: 6px;
#     color: #555;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: #fff;
# }
#
# .h5tb-dim-highlight {
#     background-color: rgba(3, 169, 244, .2);
#     cursor: pointer;
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--12950210100" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--12950210100">
#                         /<span>(4)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__db_file_type__ : piv_case</li><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.8rc2</li><li style="list-style-type: none; font-style: italic">operator : John</li>
#                     </ul>
#
#                 <ul id="ds-1-/u-12951999900" class="h5tb-var-list">
#                     <input id="ds-2-/u-12952002700" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/u-12952002700">u</label>
#                     <span class="h5tb-dims">(2, 5, 64, x: 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : u-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/v-12952645100" class="h5tb-var-list">
#                     <input id="ds-2-/v-12952648000" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/v-12952648000">v</label>
#                     <span class="h5tb-dims">(2, 5, 64, x: 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : v-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/x-12953131000" class="h5tb-var-list">
#                     <input id="ds-2-/x-12953133800" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/x-12953133800">x</label>
#                     <span class="h5tb-dims">(86) [int32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : x-coordinate</li><li style="list-style-type: none; font-style: italic">units : m</li>
#                 </ul>
#                 </ul>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds-timeAverages-12953566800" type="checkbox" >
#                         <label style="font-weight: bold" for="group-ds-timeAverages-12953566800">
#                         timeAverages<span>(2)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : time averaged data</li>
#                     </ul>
#
#                 <ul id="ds-1-/timeAverages/u-12954347700" class="h5tb-var-list">
#                     <input id="ds-2-/timeAverages/u-12954350600" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/timeAverages/u-12954350600">u</label>
#                     <span class="h5tb-dims">(2, 64, 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : mean u-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/timeAverages/v-12954693200" class="h5tb-var-list">
#                     <input id="ds-2-/timeAverages/v-12954695900" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/timeAverages/v-12954695900">v</label>
#                     <span class="h5tb-dims">(2, 64, 86, 2) [float32]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : mean v-component</li><li style="list-style-type: none; font-style: italic">units : m/s</li>
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <head><style>/*
# CSS inspired by xarray: https://github.com/pydata/xarray
# */
# .h5tb-header > div,
# .h5tb-header > ul {
#     display: inline;
#     margin-top: 0;
#     margin-bottom: 0;
# }
#
# .h5tb-dataarray-cls,
# .h5tb-dataarray-name {
#     margin-left: 2px;
#     margin-right: 10px;
# }
#
# .h5tb-dataarray-name {
#     color: #000;
# }
#
# .h5grp-sections {
#     list-style: none;
#     padding: 3px;
#     margin: 0;
# }
#
# .h5grp-sections input {
#     display: none;
# }
#
# .h5grp-sections label {
#     display: inline;
# }
#
# .h5grp-sections > li > input + label > span {
#     display: inline;
#     margin-left: 4px;
# }
#
# .h5grp-sections > li > input:checked + label > span {
#     display: none;
# }
#
# .h5grp-sections input:enabled + label {
#     cursor: pointer;
# }
#
# .h5grp-sections input:not(.h5tb-values-in) ~ ul {
#     display: none;
# }
#
# .h5grp-sections input:not(.h5tb-values-in):checked ~ ul {
#     display: block;
# }
#
# .h5grp-sections > li > input + label {
#     width: 140px;
#     color: #555;
#     font-weight: 500;
#     padding: 4px 0 2px 0;
# }
#
#
# .h5grp-sections > li > input + label:before {
#     display: inline-block;
#     content: '+';
#     font-size: 11px;
#     width: 15px;
#     text-align: center;
# }
#
# .h5grp-sections > li > input:disabled + label:before {
#     color: #777;
# }
#
# .h5grp-sections > li > input:checked + label:before {
#     content: '-';
# }
#
# .h5tb-dim-list {
#     display: inline-block !important;
#     list-style: none;
#     padding: 0;
# }
#
# .h5tb-dim-list li {
#     display: inline-block;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-dim-list:before {
#     content: '(';
# }
#
# .h5tb-dim-list:after {
#     content: ')';
# }
#
# .h5tb-dim-list li:not(:last-child):after {
#     content: ',';
# }
#
# .h5tb-has-index {
#     text-decoration: underline;
# }
#
# .h5tb-var-list {
#     list-style: none;
#     padding: 0;
#     margin: 0;
# }
#
# .h5tb-var-list > li {
#     background-color: #fcfcfc;
#     overflow: hidden;
# }
#
# .h5tb-var-list > li:nth-child(odd) {
#     background-color: #efefef;
# }
#
# .h5tb-var-list li:hover {
#     background-color: rgba(3, 169, 244, .2);
# }
#
# .h5tb-var-list li > span {
#     display: inline-block;
# }
#
# input.h5tb-varname-in + label {
#     width: 140px;
#     padding-left: 0;
#     font-weight: bold;
# }
#
# .h5tb-dataset {
#     width: 100px;
# }
#
# .h5tb-attributevalue {
#     width: 100px;
#     text-align: left;
#     color: #888;
#     white-space: nowrap;
#     font-size: 12px;
# }
#
# input.h5tb-varname-in + label:before {
#     content: ' ';
#     display: inline-block;
#     font-size: 11px;
#     width: 15px;
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     color: #aaa;
#     text-decoration: none !important;
# }
#
# input.h5tb-varname-in:enabled + label:hover:before {
#     color: #000;
# }
#
# input.h5tb-varname-in:checked + label:before {
#     color: #ccc;
# }
#
# .h5tb-dims {
#     width: 280px;
#     white-space: nowrap;
# }
#
#
# .h5tb-unit {
#     width: 96px;
#     white-space: nowrap;
#     padding-right: 2px;
#     text-align: right;
#     color: #555;
#     font-style: italic;
# }
#
# .h5tb-attr-list {
#     list-style: none;
#     background-color: #fff;
#     padding-bottom: 6px;
#     color: #555;
# }
#
# .h5tb-attr-list li,
# .h5tb-attr-list li:hover {
#     background-color: #fff;
# }
#
# .h5tb-dim-highlight {
#     background-color: rgba(3, 169, 244, .2);
#     cursor: pointer;
# }</style></head>
# <div class='h5tb-warp'>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds--12957036200" type="checkbox" checked>
#                         <label style="font-weight: bold" for="group-ds--12957036200">
#                         /<span>(1)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">__db_file_type__ : fan_case</li><li style="list-style-type: none; font-style: italic">__h5rdmtoolbox_version__ : 0.8rc2</li><li style="list-style-type: none; font-style: italic">operator : Susi</li>
#                     </ul>
#
#               <ul style="list-style-type: none;" class="h5grp-sections">
#                     <li>
#                         <input id="group-ds-operation_point-12957729400" type="checkbox" >
#                         <label style="font-weight: bold" for="group-ds-operation_point-12957729400">
#                         operation_point<span>(2)</span></label>
#
#
#                     <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : Operation point data group</li>
#                     </ul>
#
#                 <ul id="ds-1-/operation_point/ptot-12958563600" class="h5tb-var-list">
#                     <input id="ds-2-/operation_point/ptot-12958566300" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/operation_point/ptot-12958566300">ptot</label>
#                     <span class="h5tb-dims">(100) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : Pressure increase</li><li style="list-style-type: none; font-style: italic">mean : 17.19229974125778</li><li style="list-style-type: none; font-style: italic">std : 0.29116512278901857</li><li style="list-style-type: none; font-style: italic">units : Pa</li>
#                 </ul>
#                 </ul>
#
#                 <ul id="ds-1-/operation_point/vfr-12959016600" class="h5tb-var-list">
#                     <input id="ds-2-/operation_point/vfr-12959019500" class="h5tb-varname-in" type="checkbox">
#                     <label class='h5tb-varname' for="ds-2-/operation_point/vfr-12959019500">vfr</label>
#                     <span class="h5tb-dims">(100) [float64]</span>
#                 <ul class="h5tb-attr-list"><li style="list-style-type: none; font-style: italic">long_name : volume flow_utils rate</li><li style="list-style-type: none; font-style: italic">mean : 0.054229310781176085</li><li style="list-style-type: none; font-style: italic">std : 0.2831909251771927</li><li style="list-style-type: none; font-style: italic">units : m<sup>3</sup>/s</li>
#                 </ul>
#                 </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>
